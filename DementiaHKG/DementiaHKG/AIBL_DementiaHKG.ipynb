# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('NC.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'E:/code/AIBL/NC/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/AIBL/AD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('MCI.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/AIBL/MCI/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #44
print(count_no) #247
print(count_mci) #106
# Out:
# 72
# 358
# 86

# %%
# 基础替换字典
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','no':'0','yes':'1','ans':'2','haw':'3','ind':'4','bl':'1'}

# 隔离诊断标签的列索引提取规则
# EHR (2维): age(3), gender(4)
ehr_cols = [3, 4] 
# BIO (5维): apoe(5), mmse(18), cdr(19), lm_imm(20), lm_del(21)
bio_cols = [5, 18, 19, 20, 21]

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        # 仅提取安全的特征列
        extracted_row = [row[idx] for idx in target_cols]
        # 字典映射替换
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                # 拦截 NaN，保留为 np.nan 供后续专门的 Imputer 处理
                if math.isnan(val):
                    val = np.nan
            except ValueError:
                val = np.nan 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# 加权算值函数 
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
# 1. 提取 BIO 数组 (5 维特征)
ad_array = preprocess_data(data_ad, replace_dict, bio_cols)
normal_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_array = preprocess_data(data_mci, replace_dict, bio_cols)

# 2. 直接转换数据为 Tensor (无需外部线性层)
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 3. 打印结果 (预期输出类似: torch.Size([72, 5]))
print('AD_tensor shape:', ad_tensor.shape)      
print('Normal_tensor shape:', normal_tensor.shape) 
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([72, 5])
# Normal_tensor shape: torch.Size([358, 5])
# MCI_tensor shape: torch.Size([86, 5])

# %%
# 1. 提取脱敏后的 EHR 数组 (内部已通过 replace_dict 转换为数值)
ad_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_data = preprocess_data(data_mci, replace_dict, ehr_cols)

# 2. 直接转换为 Tensor (无需外部线性层)
ad_EHR = torch.from_numpy(ad_data).float()
normal_EHR = torch.from_numpy(normal_data).float()
mci_EHR = torch.from_numpy(mci_data).float()

# 3. 打印结果 (预期输出类似: torch.Size([72, 2]))
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([72, 2])
# normal.EHR---> torch.Size([358, 2])
# mci.EHR---> torch.Size([86, 2])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os
import torch
from torch.utils.data import DataLoader

def get_nii_file_list(folder_path):
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

# 1. 实例化模型，将输出维度设为64，严格匹配 Transformer
nii = CNN_3D(num_class=64)
nii = nii.to(device)
nii.eval() # 开启评估模式

def extract_mri_features(folder_path, batch_size=16):
    # 保留 AIBL 获取文件列表的逻辑
    nii_files = get_nii_file_list(folder_path)
    dataset = NiiDataset(nii_files)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_outputs = []
    
    # 2. 关闭梯度计算
    with torch.no_grad():
        for batch_idx, batch_data in enumerate(dataloader):
            batch_data = batch_data.to(device)
            output = nii(batch_data)
            # 提取后立即转回 CPU
            all_outputs.append(output.cpu())
            
    return torch.cat(all_outputs, dim=0)

# 3. 模块化调用，保留原始文件夹名称
ad_output = extract_mri_features('E:/code/AIBL/AD')
print('ad nii shape--->', ad_output.shape)

normal_output = extract_mri_features('E:/code/AIBL/NC')
print('normal nii shape--->', normal_output.shape)

mci_output = extract_mri_features('E:/code/AIBL/MCI')
print('mci nii shape--->', mci_output.shape)
# Out:
# ad nii shape---> torch.Size([72, 64])
# normal nii shape---> torch.Size([358, 64])
# mci nii shape---> torch.Size([86, 64])

# %%
import numpy as np
import torch
import pandas as pd
import json

# 1. 替换为AIBL数据集对应的图谱特征文件
ENTITY_EMB_NPY = "AIBL-DementiaHKG-Embeddings.npy"
ENTITY2ID_FILE = "AIBL-DementiaHKG-Entity2ID.json"
PATIENT_QUERY_DICT = "AIBL-DementiaHKG-Entities.json"

with open(ENTITY2ID_FILE, 'r', encoding='utf-8') as f:
    entity2id = json.load(f)

with open(PATIENT_QUERY_DICT, 'r', encoding='utf-8') as f:
    patient_entities = json.load(f)

emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
embed_dim = emb.shape[1] 

# 2. 核心修改：将序列长度下调至16，适配AIBL的数据维度
max_seq_len = 16 

def get_patient_embedding_seq(filename: str):
    filename = str(filename).strip()
    patient_data = patient_entities.get(filename, {})
    active_nodes = patient_data.get("input_nodes", [])
    
    vecs = []
    pad_masks = []
    
    # 构造固定长度为16的序列与对应的布尔掩码
    for i in range(max_seq_len):
        if i < len(active_nodes):
            node = active_nodes[i]
            if node != "[PAD]" and node in entity2id:
                vecs.append(emb[entity2id[node]])
                pad_masks.append(False)  # 保持你正确的逻辑：False代表有效节点
            else:
                vecs.append(torch.zeros(embed_dim))
                pad_masks.append(True)   # True代表PAD，让注意力机制忽略
        else:
            vecs.append(torch.zeros(embed_dim))
            pad_masks.append(True)
            
    # 返回知识序列矩阵和用于PyTorch注意力的掩码
    return torch.stack(vecs), torch.tensor(pad_masks, dtype=torch.bool)

def process_and_verify_seq(df, cohort_name):
    seq_tensors = []
    mask_tensors = []
    valid_count = 0
    
    for _, r in df.iterrows():
        seq_tensor, mask_tensor = get_patient_embedding_seq(r['filename'])
        seq_tensors.append(seq_tensor)
        mask_tensors.append(mask_tensor)
        
        # 验证是否包含至少一个有效节点（掩码中存在False）
        if not torch.all(mask_tensor):
            valid_count += 1
            
    stacked_seq = torch.stack(seq_tensors)
    stacked_mask = torch.stack(mask_tensors)
    
    print(f"[{cohort_name}] 总样本数: {len(df)} | 成功注入KG先验序列的样本数: {valid_count}")
    return stacked_seq, stacked_mask

# ==========================================
# 3. 沿用ADNI的三个独立表格提取方式
# ==========================================
print("开始提取AIBL完整知识序列与注意力掩码...")
ad_transe_seq, ad_transe_mask = process_and_verify_seq(pd.read_csv('AD.csv'), "AD")
mci_transe_seq, mci_transe_mask = process_and_verify_seq(pd.read_csv('mci.csv'), "MCI")
normal_transe_seq, normal_transe_mask = process_and_verify_seq(pd.read_csv('NC.csv'), "NC")

print("-" * 50)
print("最终生成的知识序列 Shapes:", ad_transe_seq.shape, mci_transe_seq.shape, normal_transe_seq.shape)
print("最终生成的掩码张量 Shapes:", ad_transe_mask.shape, mci_transe_mask.shape, normal_transe_mask.shape)
# Out:
# 开始提取AIBL完整知识序列与注意力掩码...
# [AD] 总样本数: 72 | 成功注入KG先验序列的样本数: 72
# [MCI] 总样本数: 86 | 成功注入KG先验序列的样本数: 86
# [NC] 总样本数: 358 | 成功注入KG先验序列的样本数: 358
# --------------------------------------------------
# 最终生成的知识序列 Shapes: torch.Size([72, 16, 128]) torch.Size([86, 16, 128]) torch.Size([358, 16, 128])
# 最终生成的掩码张量 Shapes: torch.Size([72, 16]) torch.Size([86, 16]) torch.Size([358, 16])

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# ==========================================
# 1. 组合基础多模态特征 (EHR + IMG + BIO)
# 严格匹配你的变量名：ad_EHR, ad_output, ad_tensor 等
# ==========================================
X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)

y_ad = torch.ones(len(X_ad)) * 2
y_mci = torch.ones(len(X_mci)) * 1
y_normal = torch.ones(len(X_normal)) * 0

# ==========================================
# 2. 沿着 batch 维度合并所有数据
# ==========================================
X_all = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y_all = torch.cat([y_ad, y_mci, y_normal], dim=0).long()

# 合并提取好的三维知识序列和二维掩码 (使用你代码中的 normal_transe_seq)
kg_seq_all = torch.cat([ad_transe_seq, mci_transe_seq, normal_transe_seq], dim=0).float()
kg_mask_all = torch.cat([ad_transe_mask, mci_transe_mask, normal_transe_mask], dim=0).bool()

# ==========================================
# 3. 使用索引(Index)进行一致性数据集切分
# ==========================================
indices = np.arange(len(y_all))
idx_train, idx_test, y_train, y_test = train_test_split(
    indices, y_all.numpy(), test_size=0.20, stratify=y_all.numpy(), random_state=32
)
idx_train, idx_val, y_train, y_val = train_test_split(
    idx_train, y_train, test_size=0.20, stratify=y_train, random_state=30
)

# ==========================================
# 4. 根据划分好的索引，生成并分发对应的 Tensor 到 GPU
# ==========================================
X_train_t = X_all[idx_train].to(device)
seq_train_t = kg_seq_all[idx_train].to(device)
mask_train_t = kg_mask_all[idx_train].to(device)
y_train_t = torch.tensor(y_train, dtype=torch.long).to(device)

X_val_t = X_all[idx_val].to(device)
seq_val_t = kg_seq_all[idx_val].to(device)
mask_val_t = kg_mask_all[idx_val].to(device)
y_val_t = torch.tensor(y_val, dtype=torch.long).to(device)

X_test_t = X_all[idx_test].to(device)
seq_test_t = kg_seq_all[idx_test].to(device)
mask_test_t = kg_mask_all[idx_test].to(device)
y_test_t = torch.tensor(y_test, dtype=torch.long).to(device)

# ==========================================
# 5. 封装 DataLoader (包含4个元素：X, seq, mask, y)
# ==========================================
train_dataset = TensorDataset(X_train_t, seq_train_t, mask_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, seq_val_t, mask_val_t, y_val_t)
test_dataset = TensorDataset(X_test_t, seq_test_t, mask_test_t, y_test_t)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

print("数据准备完毕！Train:", len(train_dataset), "Val:", len(val_dataset), "Test:", len(test_dataset))
# Out:
# 数据准备完毕！Train: 329 Val: 83 Test: 104

# %%
from sklearn.metrics import roc_auc_score, f1_score, recall_score, precision_score
import numpy as np

def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs, all_labels, all_preds = [], [], []
    
    # ★ 修改点：解包出4个变量
    for inputs, kg_seq, kg_mask, labels in loader:
        optimizer.zero_grad()
        
        # ★ 修改点：传入 seq 和 mask
        outputs = model(inputs, kg_seq, kg_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs, all_labels, all_preds = [], [], []
    
    with torch.no_grad():
        for inputs, kg_seq, kg_mask, labels in loader:
            outputs = model(inputs, kg_seq, kg_mask)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
import torch.optim as optim
import torch.nn as nn

# AIBL 数据集的具体参数
ehr_dim = 2
img_dim = 64
bio_dim = 5
max_seq_len = 16

num_epochs = 200
learning_rate = 1e-5
weight_decay = 1e-3

# ★ 修改点：实例化新的AIBL专属模型
model = KGMultiModalTransformer(
    ehr_dim=ehr_dim, 
    img_dim=img_dim, 
    bio_dim=bio_dim, 
    embed_dim=128,
    transe_embed_dim=128, 
    max_seq_len=max_seq_len
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_losses, train_aucs, train_f1s, train_recalls, train_precisions = [], [], [], [], []
test_losses, test_aucs, test_f1s, test_recalls, test_precisions = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    if epoch % 10 == 0: print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"Test Loss: {test_loss:.4f}, Test AUC: {test_auc:.4f}")
# Out:
# Epoch 1/200, Train Loss: 1.1293, Train AUC: 0.4805  Test Loss: 1.0571, Test AUC: 0.4938
# Epoch 2/200, Train Loss: 1.1098, Train AUC: 0.5301  Test Loss: 1.0959, Test AUC: 0.4861
# Epoch 3/200, Train Loss: 1.1047, Train AUC: 0.5276  Test Loss: 1.1002, Test AUC: 0.4935
# Epoch 4/200, Train Loss: 1.1004, Train AUC: 0.5220  Test Loss: 1.0977, Test AUC: 0.4991
# Epoch 5/200, Train Loss: 1.0836, Train AUC: 0.5623  Test Loss: 1.0854, Test AUC: 0.5102
# Epoch 6/200, Train Loss: 1.0907, Train AUC: 0.5129  Test Loss: 1.0879, Test AUC: 0.5088
# Epoch 7/200, Train Loss: 1.0634, Train AUC: 0.5912  Test Loss: 1.0741, Test AUC: 0.5252
# Epoch 8/200, Train Loss: 1.0637, Train AUC: 0.5948  Test Loss: 1.0616, Test AUC: 0.5431
# Epoch 9/200, Train Loss: 1.0733, Train AUC: 0.5799  Test Loss: 1.0625, Test AUC: 0.5437
# Epoch 10/200, Train Loss: 1.0775, Train AUC: 0.5711  Test Loss: 1.0560, Test AUC: 0.5709
# Epoch 11/200, Train Loss: 1.0611, Train AUC: 0.5865  Test Loss: 1.0557, Test AUC: 0.5875
# Epoch 12/200, Train Loss: 1.0430, Train AUC: 0.6289  Test Loss: 1.0428, Test AUC: 0.5773
# Epoch 13/200, Train Loss: 1.0619, Train AUC: 0.5834  Test Loss: 1.0383, Test AUC: 0.5878
# Epoch 14/200, Train Loss: 1.0525, Train AUC: 0.5778  Test Loss: 1.0328, Test AUC: 0.5969
# Epoch 15/200, Train Loss: 1.0205, Train AUC: 0.6570  Test Loss: 1.0282, Test AUC: 0.6091
# Epoch 16/200, Train Loss: 1.0301, Train AUC: 0.6454  Test Loss: 1.0165, Test AUC: 0.6227
# Epoch 17/200, Train Loss: 1.0313, Train AUC: 0.6286  Test Loss: 1.0006, Test AUC: 0.6329
# Epoch 18/200, Train Loss: 1.0132, Train AUC: 0.6510  Test Loss: 1.0062, Test AUC: 0.6421
# Epoch 19/200, Train Loss: 1.0332, Train AUC: 0.6449  Test Loss: 0.9895, Test AUC: 0.6460
# Epoch 20/200, Train Loss: 0.9856, Train AUC: 0.6726  Test Loss: 0.9856, Test AUC: 0.6447
# Epoch 21/200, Train Loss: 0.9796, Train AUC: 0.7020  Test Loss: 0.9875, Test AUC: 0.6580
# Epoch 22/200, Train Loss: 0.9874, Train AUC: 0.7109  Test Loss: 0.9805, Test AUC: 0.6683
# Epoch 23/200, Train Loss: 0.9791, Train AUC: 0.6947  Test Loss: 0.9666, Test AUC: 0.6769
# Epoch 24/200, Train Loss: 0.9456, Train AUC: 0.7413  Test Loss: 0.9622, Test AUC: 0.6813
# Epoch 25/200, Train Loss: 0.9536, Train AUC: 0.7461  Test Loss: 0.9530, Test AUC: 0.6820
# Epoch 26/200, Train Loss: 0.9427, Train AUC: 0.7344  Test Loss: 0.9472, Test AUC: 0.6890
# Epoch 27/200, Train Loss: 0.9767, Train AUC: 0.7297  Test Loss: 0.9320, Test AUC: 0.6948
# Epoch 28/200, Train Loss: 0.9476, Train AUC: 0.7692  Test Loss: 0.9365, Test AUC: 0.6963
# Epoch 29/200, Train Loss: 0.9496, Train AUC: 0.7339  Test Loss: 0.9276, Test AUC: 0.7016
# Epoch 30/200, Train Loss: 0.9169, Train AUC: 0.8005  Test Loss: 0.9281, Test AUC: 0.7119
# Epoch 31/200, Train Loss: 0.9180, Train AUC: 0.7907  Test Loss: 0.9086, Test AUC: 0.7198
# Epoch 32/200, Train Loss: 0.9306, Train AUC: 0.7787  Test Loss: 0.9076, Test AUC: 0.7236
# Epoch 33/200, Train Loss: 0.9019, Train AUC: 0.8020  Test Loss: 0.9012, Test AUC: 0.7332
# Epoch 34/200, Train Loss: 0.8984, Train AUC: 0.7924  Test Loss: 0.8877, Test AUC: 0.7282
# Epoch 35/200, Train Loss: 0.8951, Train AUC: 0.7931  Test Loss: 0.8837, Test AUC: 0.7296
# Epoch 36/200, Train Loss: 0.9234, Train AUC: 0.7672  Test Loss: 0.8724, Test AUC: 0.7446
# Epoch 37/200, Train Loss: 0.8953, Train AUC: 0.8047  Test Loss: 0.8740, Test AUC: 0.7498
# Epoch 38/200, Train Loss: 0.8947, Train AUC: 0.7994  Test Loss: 0.8702, Test AUC: 0.7497
# Epoch 39/200, Train Loss: 0.8827, Train AUC: 0.8068  Test Loss: 0.8616, Test AUC: 0.7473
# Epoch 40/200, Train Loss: 0.9066, Train AUC: 0.7462  Test Loss: 0.8566, Test AUC: 0.7499
# Epoch 41/200, Train Loss: 0.8761, Train AUC: 0.7910  Test Loss: 0.8543, Test AUC: 0.7472
# Epoch 42/200, Train Loss: 0.8920, Train AUC: 0.7844  Test Loss: 0.8536, Test AUC: 0.7509
# Epoch 43/200, Train Loss: 0.8730, Train AUC: 0.8139  Test Loss: 0.8500, Test AUC: 0.7576
# Epoch 44/200, Train Loss: 0.8666, Train AUC: 0.8351  Test Loss: 0.8368, Test AUC: 0.7508
# Epoch 45/200, Train Loss: 0.8439, Train AUC: 0.8511  Test Loss: 0.8332, Test AUC: 0.7575
# Epoch 46/200, Train Loss: 0.8550, Train AUC: 0.8152  Test Loss: 0.8376, Test AUC: 0.7600
# Epoch 47/200, Train Loss: 0.8528, Train AUC: 0.8208  Test Loss: 0.8192, Test AUC: 0.7634
# Epoch 48/200, Train Loss: 0.8447, Train AUC: 0.8307  Test Loss: 0.8194, Test AUC: 0.7693
# Epoch 49/200, Train Loss: 0.8258, Train AUC: 0.8516  Test Loss: 0.8305, Test AUC: 0.7640
# Epoch 50/200, Train Loss: 0.8100, Train AUC: 0.8543  Test Loss: 0.8074, Test AUC: 0.7612
# Epoch 51/200, Train Loss: 0.8314, Train AUC: 0.8325  Test Loss: 0.8068, Test AUC: 0.7683
# Epoch 52/200, Train Loss: 0.8470, Train AUC: 0.8194  Test Loss: 0.7950, Test AUC: 0.7801
# Epoch 53/200, Train Loss: 0.8108, Train AUC: 0.8666  Test Loss: 0.7918, Test AUC: 0.7779
# Epoch 54/200, Train Loss: 0.8366, Train AUC: 0.8283  Test Loss: 0.7944, Test AUC: 0.7763
# Epoch 55/200, Train Loss: 0.8013, Train AUC: 0.8544  Test Loss: 0.7929, Test AUC: 0.7773
# Epoch 56/200, Train Loss: 0.8114, Train AUC: 0.8425  Test Loss: 0.7827, Test AUC: 0.7909
# Epoch 57/200, Train Loss: 0.8131, Train AUC: 0.8368  Test Loss: 0.7736, Test AUC: 0.7884
# Epoch 58/200, Train Loss: 0.8101, Train AUC: 0.8493  Test Loss: 0.7648, Test AUC: 0.7738
# Epoch 59/200, Train Loss: 0.8324, Train AUC: 0.8202  Test Loss: 0.7637, Test AUC: 0.7884
# Epoch 60/200, Train Loss: 0.8012, Train AUC: 0.8503  Test Loss: 0.7630, Test AUC: 0.7968
# Epoch 61/200, Train Loss: 0.7918, Train AUC: 0.8690  Test Loss: 0.7607, Test AUC: 0.7947
# Epoch 62/200, Train Loss: 0.7620, Train AUC: 0.8848  Test Loss: 0.7449, Test AUC: 0.7858
# Epoch 63/200, Train Loss: 0.7730, Train AUC: 0.8666  Test Loss: 0.7425, Test AUC: 0.7848
# Epoch 64/200, Train Loss: 0.7824, Train AUC: 0.8732  Test Loss: 0.7351, Test AUC: 0.7934
# Epoch 65/200, Train Loss: 0.7633, Train AUC: 0.8604  Test Loss: 0.7392, Test AUC: 0.7833
# Epoch 66/200, Train Loss: 0.7719, Train AUC: 0.8581  Test Loss: 0.7489, Test AUC: 0.7909
# Epoch 67/200, Train Loss: 0.7690, Train AUC: 0.8645  Test Loss: 0.7392, Test AUC: 0.7902
# Epoch 68/200, Train Loss: 0.7368, Train AUC: 0.8949  Test Loss: 0.7261, Test AUC: 0.7984
# Epoch 69/200, Train Loss: 0.7416, Train AUC: 0.8808  Test Loss: 0.7331, Test AUC: 0.8022
# Epoch 70/200, Train Loss: 0.7433, Train AUC: 0.8951  Test Loss: 0.7228, Test AUC: 0.7879
# Epoch 71/200, Train Loss: 0.7405, Train AUC: 0.8932  Test Loss: 0.7239, Test AUC: 0.8016
# Epoch 72/200, Train Loss: 0.7356, Train AUC: 0.8852  Test Loss: 0.7074, Test AUC: 0.8063
# Epoch 73/200, Train Loss: 0.7246, Train AUC: 0.9054  Test Loss: 0.7043, Test AUC: 0.8032
# Epoch 74/200, Train Loss: 0.7330, Train AUC: 0.8747  Test Loss: 0.6990, Test AUC: 0.8080
# Epoch 75/200, Train Loss: 0.7415, Train AUC: 0.8647  Test Loss: 0.7002, Test AUC: 0.8109
# Epoch 76/200, Train Loss: 0.7175, Train AUC: 0.8686  Test Loss: 0.6998, Test AUC: 0.8064
# Epoch 77/200, Train Loss: 0.7158, Train AUC: 0.8883  Test Loss: 0.6944, Test AUC: 0.8164
# Epoch 78/200, Train Loss: 0.7343, Train AUC: 0.8983  Test Loss: 0.6931, Test AUC: 0.8213
# Epoch 79/200, Train Loss: 0.7086, Train AUC: 0.8960  Test Loss: 0.6963, Test AUC: 0.8252
# Epoch 80/200, Train Loss: 0.7061, Train AUC: 0.8829  Test Loss: 0.6907, Test AUC: 0.8212
# Epoch 81/200, Train Loss: 0.6978, Train AUC: 0.9066  Test Loss: 0.6941, Test AUC: 0.8117
# Epoch 82/200, Train Loss: 0.7127, Train AUC: 0.8957  Test Loss: 0.6831, Test AUC: 0.8165
# Epoch 83/200, Train Loss: 0.7037, Train AUC: 0.9107  Test Loss: 0.6890, Test AUC: 0.8196
# Epoch 84/200, Train Loss: 0.6916, Train AUC: 0.8861  Test Loss: 0.6718, Test AUC: 0.8193
# Epoch 85/200, Train Loss: 0.6882, Train AUC: 0.9009  Test Loss: 0.6654, Test AUC: 0.8317
# Epoch 86/200, Train Loss: 0.7131, Train AUC: 0.8884  Test Loss: 0.6824, Test AUC: 0.8361
# Epoch 87/200, Train Loss: 0.7012, Train AUC: 0.8914  Test Loss: 0.6662, Test AUC: 0.8323
# Epoch 88/200, Train Loss: 0.6844, Train AUC: 0.8993  Test Loss: 0.6698, Test AUC: 0.8114
# Epoch 89/200, Train Loss: 0.6864, Train AUC: 0.8967  Test Loss: 0.6570, Test AUC: 0.8161
# Epoch 90/200, Train Loss: 0.6815, Train AUC: 0.8986  Test Loss: 0.6526, Test AUC: 0.8187
# Epoch 91/200, Train Loss: 0.6964, Train AUC: 0.8706  Test Loss: 0.6436, Test AUC: 0.8236
# Epoch 92/200, Train Loss: 0.6838, Train AUC: 0.8925  Test Loss: 0.6444, Test AUC: 0.8368
# Epoch 93/200, Train Loss: 0.6793, Train AUC: 0.8962  Test Loss: 0.6436, Test AUC: 0.8392
# Epoch 94/200, Train Loss: 0.6758, Train AUC: 0.8874  Test Loss: 0.6368, Test AUC: 0.8209
# Epoch 95/200, Train Loss: 0.6943, Train AUC: 0.8656  Test Loss: 0.6485, Test AUC: 0.8219
# Epoch 96/200, Train Loss: 0.6755, Train AUC: 0.8950  Test Loss: 0.6269, Test AUC: 0.8116
# Epoch 97/200, Train Loss: 0.6770, Train AUC: 0.8800  Test Loss: 0.6442, Test AUC: 0.8276
# Epoch 98/200, Train Loss: 0.6689, Train AUC: 0.9165  Test Loss: 0.6248, Test AUC: 0.8238
# Epoch 99/200, Train Loss: 0.6581, Train AUC: 0.8921  Test Loss: 0.6240, Test AUC: 0.8354
# Epoch 100/200, Train Loss: 0.6432, Train AUC: 0.9025  Test Loss: 0.6248, Test AUC: 0.8282
# Epoch 101/200, Train Loss: 0.6622, Train AUC: 0.8947  Test Loss: 0.6299, Test AUC: 0.8226
# Epoch 102/200, Train Loss: 0.6498, Train AUC: 0.8979  Test Loss: 0.6323, Test AUC: 0.8355
# Epoch 103/200, Train Loss: 0.6326, Train AUC: 0.9259  Test Loss: 0.6277, Test AUC: 0.8370
# Epoch 104/200, Train Loss: 0.6500, Train AUC: 0.8885  Test Loss: 0.6286, Test AUC: 0.8326
# Epoch 105/200, Train Loss: 0.6453, Train AUC: 0.9089  Test Loss: 0.6318, Test AUC: 0.8317
# Epoch 106/200, Train Loss: 0.6570, Train AUC: 0.8952  Test Loss: 0.6151, Test AUC: 0.8420
# Epoch 107/200, Train Loss: 0.6356, Train AUC: 0.9050  Test Loss: 0.6246, Test AUC: 0.8304
# Epoch 108/200, Train Loss: 0.6670, Train AUC: 0.8707  Test Loss: 0.6179, Test AUC: 0.8423
# Epoch 109/200, Train Loss: 0.6476, Train AUC: 0.9070  Test Loss: 0.6115, Test AUC: 0.8518
# Epoch 110/200, Train Loss: 0.6312, Train AUC: 0.9134  Test Loss: 0.6029, Test AUC: 0.8563
# Epoch 111/200, Train Loss: 0.6348, Train AUC: 0.9045  Test Loss: 0.6176, Test AUC: 0.8406
# Epoch 112/200, Train Loss: 0.6154, Train AUC: 0.9065  Test Loss: 0.6108, Test AUC: 0.8322
# Epoch 113/200, Train Loss: 0.6525, Train AUC: 0.8875  Test Loss: 0.6023, Test AUC: 0.8457
# Epoch 114/200, Train Loss: 0.6101, Train AUC: 0.9167  Test Loss: 0.6115, Test AUC: 0.8352
# Epoch 115/200, Train Loss: 0.6224, Train AUC: 0.9111  Test Loss: 0.5957, Test AUC: 0.8372
# Epoch 116/200, Train Loss: 0.6169, Train AUC: 0.9194  Test Loss: 0.6105, Test AUC: 0.8373
# Epoch 117/200, Train Loss: 0.6427, Train AUC: 0.8984  Test Loss: 0.6021, Test AUC: 0.8376
# Epoch 118/200, Train Loss: 0.6162, Train AUC: 0.9062  Test Loss: 0.5930, Test AUC: 0.8457
# Epoch 119/200, Train Loss: 0.6063, Train AUC: 0.9209  Test Loss: 0.5848, Test AUC: 0.8566
# Epoch 120/200, Train Loss: 0.6149, Train AUC: 0.9124  Test Loss: 0.5912, Test AUC: 0.8565
# Epoch 121/200, Train Loss: 0.6172, Train AUC: 0.9231  Test Loss: 0.5843, Test AUC: 0.8558
# Epoch 122/200, Train Loss: 0.6214, Train AUC: 0.9138  Test Loss: 0.5948, Test AUC: 0.8553
# Epoch 123/200, Train Loss: 0.6434, Train AUC: 0.8812  Test Loss: 0.5815, Test AUC: 0.8527
# Epoch 124/200, Train Loss: 0.6033, Train AUC: 0.9067  Test Loss: 0.5768, Test AUC: 0.8368
# Epoch 125/200, Train Loss: 0.6068, Train AUC: 0.9200  Test Loss: 0.5764, Test AUC: 0.8325
# Epoch 126/200, Train Loss: 0.5929, Train AUC: 0.9116  Test Loss: 0.5816, Test AUC: 0.8327
# Epoch 127/200, Train Loss: 0.6227, Train AUC: 0.8786  Test Loss: 0.5796, Test AUC: 0.8381
# Epoch 128/200, Train Loss: 0.5875, Train AUC: 0.9283  Test Loss: 0.5798, Test AUC: 0.8427
# Epoch 129/200, Train Loss: 0.6393, Train AUC: 0.8697  Test Loss: 0.5776, Test AUC: 0.8391
# Epoch 130/200, Train Loss: 0.6141, Train AUC: 0.9020  Test Loss: 0.5753, Test AUC: 0.8226
# Epoch 131/200, Train Loss: 0.6003, Train AUC: 0.9023  Test Loss: 0.5699, Test AUC: 0.8446
# Epoch 132/200, Train Loss: 0.6253, Train AUC: 0.8842  Test Loss: 0.5752, Test AUC: 0.8478
# Epoch 133/200, Train Loss: 0.6132, Train AUC: 0.9088  Test Loss: 0.5719, Test AUC: 0.8607
# Epoch 134/200, Train Loss: 0.5948, Train AUC: 0.9140  Test Loss: 0.5773, Test AUC: 0.8636
# Epoch 135/200, Train Loss: 0.6045, Train AUC: 0.9243  Test Loss: 0.5707, Test AUC: 0.8616
# Epoch 136/200, Train Loss: 0.5858, Train AUC: 0.9275  Test Loss: 0.5655, Test AUC: 0.8352
# Epoch 137/200, Train Loss: 0.5816, Train AUC: 0.9038  Test Loss: 0.5674, Test AUC: 0.8460
# Epoch 138/200, Train Loss: 0.5997, Train AUC: 0.9299  Test Loss: 0.5758, Test AUC: 0.8529
# Epoch 139/200, Train Loss: 0.5709, Train AUC: 0.9370  Test Loss: 0.5682, Test AUC: 0.8570
# Epoch 140/200, Train Loss: 0.5895, Train AUC: 0.9048  Test Loss: 0.5698, Test AUC: 0.8500
# Epoch 141/200, Train Loss: 0.5906, Train AUC: 0.9046  Test Loss: 0.5566, Test AUC: 0.8536
# Epoch 142/200, Train Loss: 0.5954, Train AUC: 0.9060  Test Loss: 0.5548, Test AUC: 0.8459
# Epoch 143/200, Train Loss: 0.5799, Train AUC: 0.9172  Test Loss: 0.5631, Test AUC: 0.8461
# Epoch 144/200, Train Loss: 0.5839, Train AUC: 0.9127  Test Loss: 0.5611, Test AUC: 0.8438
# Epoch 145/200, Train Loss: 0.5570, Train AUC: 0.9286  Test Loss: 0.5485, Test AUC: 0.8382
# Epoch 146/200, Train Loss: 0.5843, Train AUC: 0.9147  Test Loss: 0.5483, Test AUC: 0.8511
# Epoch 147/200, Train Loss: 0.5979, Train AUC: 0.8958  Test Loss: 0.5510, Test AUC: 0.8517
# Epoch 148/200, Train Loss: 0.5739, Train AUC: 0.9185  Test Loss: 0.5574, Test AUC: 0.8474
# Epoch 149/200, Train Loss: 0.5648, Train AUC: 0.9223  Test Loss: 0.5531, Test AUC: 0.8441
# Epoch 150/200, Train Loss: 0.5764, Train AUC: 0.9155  Test Loss: 0.5510, Test AUC: 0.8415
# Epoch 151/200, Train Loss: 0.5723, Train AUC: 0.9076  Test Loss: 0.5532, Test AUC: 0.8559
# Epoch 152/200, Train Loss: 0.5733, Train AUC: 0.9319  Test Loss: 0.5376, Test AUC: 0.8602
# Epoch 153/200, Train Loss: 0.5739, Train AUC: 0.9321  Test Loss: 0.5389, Test AUC: 0.8494
# Epoch 154/200, Train Loss: 0.5803, Train AUC: 0.8853  Test Loss: 0.5452, Test AUC: 0.8496
# Epoch 155/200, Train Loss: 0.5640, Train AUC: 0.9236  Test Loss: 0.5508, Test AUC: 0.8554
# Epoch 156/200, Train Loss: 0.5566, Train AUC: 0.9172  Test Loss: 0.5464, Test AUC: 0.8525
# Epoch 157/200, Train Loss: 0.5767, Train AUC: 0.9227  Test Loss: 0.5505, Test AUC: 0.8669
# Epoch 158/200, Train Loss: 0.5687, Train AUC: 0.9192  Test Loss: 0.5360, Test AUC: 0.8619
# Epoch 159/200, Train Loss: 0.5273, Train AUC: 0.9379  Test Loss: 0.5331, Test AUC: 0.8516
# Epoch 160/200, Train Loss: 0.5740, Train AUC: 0.9206  Test Loss: 0.5414, Test AUC: 0.8638
# Epoch 161/200, Train Loss: 0.5414, Train AUC: 0.9214  Test Loss: 0.5541, Test AUC: 0.8464
# Epoch 162/200, Train Loss: 0.5520, Train AUC: 0.9201  Test Loss: 0.5464, Test AUC: 0.8503
# Epoch 163/200, Train Loss: 0.5688, Train AUC: 0.9302  Test Loss: 0.5358, Test AUC: 0.8597
# Epoch 164/200, Train Loss: 0.5916, Train AUC: 0.9123  Test Loss: 0.5317, Test AUC: 0.8564
# Epoch 165/200, Train Loss: 0.5560, Train AUC: 0.9164  Test Loss: 0.5275, Test AUC: 0.8462
# Epoch 166/200, Train Loss: 0.5618, Train AUC: 0.9161  Test Loss: 0.5245, Test AUC: 0.8571
# Epoch 167/200, Train Loss: 0.5773, Train AUC: 0.8982  Test Loss: 0.5285, Test AUC: 0.8474
# Epoch 168/200, Train Loss: 0.5847, Train AUC: 0.8962  Test Loss: 0.5359, Test AUC: 0.8598
# Epoch 169/200, Train Loss: 0.5293, Train AUC: 0.9358  Test Loss: 0.5396, Test AUC: 0.8563
# Epoch 170/200, Train Loss: 0.5425, Train AUC: 0.9211  Test Loss: 0.5427, Test AUC: 0.8499
# Epoch 171/200, Train Loss: 0.5246, Train AUC: 0.9380  Test Loss: 0.5270, Test AUC: 0.8464
# Epoch 172/200, Train Loss: 0.5436, Train AUC: 0.9341  Test Loss: 0.5277, Test AUC: 0.8491
# Epoch 173/200, Train Loss: 0.5637, Train AUC: 0.9101  Test Loss: 0.5213, Test AUC: 0.8656
# Epoch 174/200, Train Loss: 0.5705, Train AUC: 0.9127  Test Loss: 0.5175, Test AUC: 0.8495
# Epoch 175/200, Train Loss: 0.5518, Train AUC: 0.9248  Test Loss: 0.5194, Test AUC: 0.8593
# Epoch 176/200, Train Loss: 0.5612, Train AUC: 0.9229  Test Loss: 0.5341, Test AUC: 0.8650
# Epoch 177/200, Train Loss: 0.5520, Train AUC: 0.9288  Test Loss: 0.5409, Test AUC: 0.8579
# Epoch 178/200, Train Loss: 0.5341, Train AUC: 0.9207  Test Loss: 0.5340, Test AUC: 0.8648
# Epoch 179/200, Train Loss: 0.5529, Train AUC: 0.9085  Test Loss: 0.5164, Test AUC: 0.8491
# Epoch 180/200, Train Loss: 0.5187, Train AUC: 0.9249  Test Loss: 0.5173, Test AUC: 0.8590
# Epoch 181/200, Train Loss: 0.5721, Train AUC: 0.9094  Test Loss: 0.5312, Test AUC: 0.8652
# Epoch 182/200, Train Loss: 0.5557, Train AUC: 0.9065  Test Loss: 0.5279, Test AUC: 0.8607
# Epoch 183/200, Train Loss: 0.5291, Train AUC: 0.9129  Test Loss: 0.5306, Test AUC: 0.8554
# Epoch 184/200, Train Loss: 0.5405, Train AUC: 0.9278  Test Loss: 0.5241, Test AUC: 0.8620
# Epoch 185/200, Train Loss: 0.5709, Train AUC: 0.9038  Test Loss: 0.5168, Test AUC: 0.8345
# Epoch 186/200, Train Loss: 0.5273, Train AUC: 0.9206  Test Loss: 0.5239, Test AUC: 0.8498
# Epoch 187/200, Train Loss: 0.5227, Train AUC: 0.9262  Test Loss: 0.5312, Test AUC: 0.8397
# Epoch 188/200, Train Loss: 0.5488, Train AUC: 0.9222  Test Loss: 0.5279, Test AUC: 0.8620
# Epoch 189/200, Train Loss: 0.5298, Train AUC: 0.9053  Test Loss: 0.5239, Test AUC: 0.8580
# Epoch 190/200, Train Loss: 0.5248, Train AUC: 0.9302  Test Loss: 0.5183, Test AUC: 0.8536
# Epoch 191/200, Train Loss: 0.5552, Train AUC: 0.9195  Test Loss: 0.5188, Test AUC: 0.8689
# Epoch 192/200, Train Loss: 0.5293, Train AUC: 0.9219  Test Loss: 0.5191, Test AUC: 0.8558
# Epoch 193/200, Train Loss: 0.5313, Train AUC: 0.9243  Test Loss: 0.5132, Test AUC: 0.8625
# Epoch 194/200, Train Loss: 0.5268, Train AUC: 0.9271  Test Loss: 0.5132, Test AUC: 0.8658
# Epoch 195/200, Train Loss: 0.5108, Train AUC: 0.9435  Test Loss: 0.5116, Test AUC: 0.8730
# Epoch 196/200, Train Loss: 0.5401, Train AUC: 0.9166  Test Loss: 0.5241, Test AUC: 0.8469
# Epoch 197/200, Train Loss: 0.5657, Train AUC: 0.9175  Test Loss: 0.5218, Test AUC: 0.8573
# Epoch 198/200, Train Loss: 0.5479, Train AUC: 0.9092  Test Loss: 0.5233, Test AUC: 0.8630
# Epoch 199/200, Train Loss: 0.4960, Train AUC: 0.9443  Test Loss: 0.5195, Test AUC: 0.8518
# Epoch 200/200, Train Loss: 0.4933, Train AUC: 0.9413  Test Loss: 0.5144, Test AUC: 0.8501

# %%
from sklearn.metrics import accuracy_score

model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for inputs, kg_seq, kg_mask, labels in val_loader:
        # 已经在 DataLoader 初始化时 to(device) 了，但写上以防万一
        inputs, kg_seq, kg_mask = inputs.to(device), kg_seq.to(device), kg_mask.to(device)
        
        outputs = model(inputs, kg_seq, kg_mask)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.8193
# Recall:    0.6841
# F1 Score:  0.6741
# Precision: 0.6795
# AUC-ROC:   0.8763

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("AIBL AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.savefig('AIBL_DementiaHKG_plot.png', dpi=300)
plt.close()
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("AIBL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.savefig('AIBL_DementiaHKG_plot.png', dpi=300)
plt.close()

# %%
from torchinfo import summary
import torch

model = model.to(device)

# ★ 修改点1：总特征维度 = 2 (EHR) + 64 (img) + 5 (bio) = 71
dummy_x = torch.randn(32, 71).to(device)

# ★ 修改点2：AIBL的序列长度 max_seq_len 为 16
dummy_seq = torch.randn(32, 16, 128).to(device)
dummy_mask = torch.zeros(32, 16, dtype=torch.bool).to(device)

model_stats = summary(
    model, 
    input_data=(dummy_x, dummy_seq, dummy_mask), 
    col_names=["input_size", "output_size", "num_params", "trainable"],
    verbose=1
)

print(model_stats)
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# KGMultiModalTransformer                  [32, 71]                  [32, 3]                   --                        True
# ├─Sequential: 1-1                        [32, 2]                   [32, 128]                 --                        True
# │    └─Linear: 2-1                       [32, 2]                   [32, 8]                   24                        True
# │    └─BatchNorm1d: 2-2                  [32, 8]                   [32, 8]                   16                        True
# │    └─ReLU: 2-3                         [32, 8]                   [32, 8]                   --                        --
# │    └─Linear: 2-4                       [32, 8]                   [32, 128]                 1,152                     True
# │    └─BatchNorm1d: 2-5                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-6                         [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-2                        [32, 64]                  [32, 128]                 --                        True
# │    └─Linear: 2-7                       [32, 64]                  [32, 32]                  2,080                     True
# │    └─BatchNorm1d: 2-8                  [32, 32]                  [32, 32]                  64                        True
# │    └─ReLU: 2-9                         [32, 32]                  [32, 32]                  --                        --
# │    └─Dropout: 2-10                     [32, 32]                  [32, 32]                  --                        --
# │    └─Linear: 2-11                      [32, 32]                  [32, 128]                 4,224                     True
# │    └─BatchNorm1d: 2-12                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-13                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-3                        [32, 5]                   [32, 128]                 --                        True
# │    └─Linear: 2-14                      [32, 5]                   [32, 16]                  96                        True
# │    └─BatchNorm1d: 2-15                 [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-16                        [32, 16]                  [32, 16]                  --                        --
# │    └─Dropout: 2-17                     [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-18                      [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-19                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-20                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-4                        [32, 16, 128]             [32, 16, 128]             --                        True
# │    └─Linear: 2-21                      [32, 16, 128]             [32, 16, 64]              8,256                     True
# │    └─ReLU: 2-22                        [32, 16, 64]              [32, 16, 64]              --                        --
# │    └─Dropout: 2-23                     [32, 16, 64]              [32, 16, 64]              --                        --
# │    └─Linear: 2-24                      [32, 16, 64]              [32, 16, 128]             8,320                     True
# ├─MultiheadAttention: 1-5                --                        [32, 1, 128]              66,048                    True
# ├─MultiheadAttention: 1-6                --                        [32, 1, 128]              66,048                    True
# ├─LayerNorm: 1-7                         [32, 1, 128]              [32, 1, 128]              256                       True
# ├─LayerNorm: 1-8                         [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Linear: 1-9                            [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-10                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-11                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-12                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-13                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-14                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─MultiheadAttention: 1-15               --                        [32, 1, 128]              66,048                    True
# ├─MultiheadAttention: 1-16               --                        [32, 1, 128]              (recursive)               True
# ├─LayerNorm: 1-17                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─LayerNorm: 1-18                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Sequential: 1-19                       [32, 256]                 [32, 128]                 --                        True
# │    └─Linear: 2-25                      [32, 256]                 [32, 128]                 32,896                    True
# │    └─ReLU: 2-26                        [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-27                     [32, 128]                 [32, 128]                 --                        --
# ├─Linear: 1-20                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─MultiheadAttention: 1-21               --                        [32, 1, 128]              (recursive)               True
# ├─LayerNorm: 1-22                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Sequential: 1-23                       [32, 256]                 [32, 3]                   --                        True
# │    └─Linear: 2-28                      [32, 256]                 [32, 64]                  16,448                    True
# │    └─BatchNorm1d: 2-29                 [32, 64]                  [32, 64]                  128                       True
# │    └─ReLU: 2-30                        [32, 64]                  [32, 64]                  --                        --
# │    └─Dropout: 2-31                     [32, 64]                  [32, 64]                  --                        --
# │    └─Linear: 2-32                      [32, 64]                  [32, 3]                   195                       True
# ============================================================================================================================================
# Total params: 391,883
# Trainable params: 391,883
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.20
# ============================================================================================================================================
# Input size (MB): 0.27
# Forward/backward pass size (MB): 1.47
# Params size (MB): 0.77
# Estimated Total Size (MB): 2.52
# ============================================================================================================================================
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# KGMultiModalTransformer                  [32, 71]                  [32, 3]                   --                        True
# ├─Sequential: 1-1                        [32, 2]                   [32, 128]                 --                        True
# │    └─Linear: 2-1                       [32, 2]                   [32, 8]                   24                        True
# │    └─BatchNorm1d: 2-2                  [32, 8]                   [32, 8]                   16                        True
# │    └─ReLU: 2-3                         [32, 8]                   [32, 8]                   --                        --
# │    └─Linear: 2-4                       [32, 8]                   [32, 128]                 1,152                     True
# │    └─BatchNorm1d: 2-5                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-6                         [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-2                        [32, 64]                  [32, 128]                 --                        True
# │    └─Linear: 2-7                       [32, 64]                  [32, 32]                  2,080                     True
# │    └─BatchNorm1d: 2-8                  [32, 32]                  [32, 32]                  64                        True
# │    └─ReLU: 2-9                         [32, 32]                  [32, 32]                  --                        --
# │    └─Dropout: 2-10                     [32, 32]                  [32, 32]                  --                        --
# │    └─Linear: 2-11                      [32, 32]                  [32, 128]                 4,224                     True
# │    └─BatchNorm1d: 2-12                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-13                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-3                        [32, 5]                   [32, 128]                 --                        True
# │    └─Linear: 2-14                      [32, 5]                   [32, 16]                  96                        True
# │    └─BatchNorm1d: 2-15                 [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-16                        [32, 16]                  [32, 16]                  --                        --
# │    └─Dropout: 2-17                     [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-18                      [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-19                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-20                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-4                        [32, 16, 128]             [32, 16, 128]             --                        True
# │    └─Linear: 2-21                      [32, 16, 128]             [32, 16, 64]              8,256                     True
# │    └─ReLU: 2-22                        [32, 16, 64]              [32, 16, 64]              --                        --
# │    └─Dropout: 2-23                     [32, 16, 64]              [32, 16, 64]              --                        --
# │    └─Linear: 2-24                      [32, 16, 64]              [32, 16, 128]             8,320                     True
# ├─MultiheadAttention: 1-5                --                        [32, 1, 128]              66,048                    True
# ├─MultiheadAttention: 1-6                --                        [32, 1, 128]              66,048                    True
# ├─LayerNorm: 1-7                         [32, 1, 128]              [32, 1, 128]              256                       True
# ├─LayerNorm: 1-8                         [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Linear: 1-9                            [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-10                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-11                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-12                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-13                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─Linear: 1-14                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─MultiheadAttention: 1-15               --                        [32, 1, 128]              66,048                    True
# ├─MultiheadAttention: 1-16               --                        [32, 1, 128]              (recursive)               True
# ├─LayerNorm: 1-17                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─LayerNorm: 1-18                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Sequential: 1-19                       [32, 256]                 [32, 128]                 --                        True
# │    └─Linear: 2-25                      [32, 256]                 [32, 128]                 32,896                    True
# │    └─ReLU: 2-26                        [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-27                     [32, 128]                 [32, 128]                 --                        --
# ├─Linear: 1-20                           [32, 1, 128]              [32, 1, 128]              16,512                    True
# ├─MultiheadAttention: 1-21               --                        [32, 1, 128]              (recursive)               True
# ├─LayerNorm: 1-22                        [32, 1, 128]              [32, 1, 128]              256                       True
# ├─Sequential: 1-23                       [32, 256]                 [32, 3]                   --                        True
# │    └─Linear: 2-28                      [32, 256]                 [32, 64]                  16,448                    True
# │    └─BatchNorm1d: 2-29                 [32, 64]                  [32, 64]                  128                       True
# │    └─ReLU: 2-30                        [32, 64]                  [32, 64]                  --                        --
# │    └─Dropout: 2-31                     [32, 64]                  [32, 64]                  --                        --
# │    └─Linear: 2-32                      [32, 64]                  [32, 3]                   195                       True
# ============================================================================================================================================
# Total params: 391,883
# Trainable params: 391,883
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.20
# ============================================================================================================================================
# Input size (MB): 0.27
# Forward/backward pass size (MB): 1.47
# Params size (MB): 0.77
# Estimated Total Size (MB): 2.52
# ============================================================================================================================================
