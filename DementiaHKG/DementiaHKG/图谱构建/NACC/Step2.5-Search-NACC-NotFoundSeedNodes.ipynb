# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

RAW_KG_PATH = "kg.csv"

def precise_search_missed_nodes():
    print("==================================================")
    print("🎯 启动未命中节点精准检索...")
    
    try:
        df = pd.read_csv(RAW_KG_PATH, low_memory=False)
    except FileNotFoundError:
        print("❌ 找不到 kg.csv，请检查路径。")
        return

    target_types = ['disease', 'effect/phenotype']
    search_df = df[df['x_type'].isin(target_types)]
    
    missed_terms = {
        "房颤 (AFIB)": "atrial fibrillation",
        "短暂性脑缺血 (TIA)": "transient ischemic attack",
        "脑外伤 (TBI)": "traumatic brain",
        "高胆固醇 (HYPERCHO)": "hypercholesterolemia",
        "糖尿病 (DIABETES)": "diabetes"
    }
    
    for name, keyword in missed_terms.items():
        print(f"\n▶ 正在精准检索【{name}】...")
        
        mask = search_df['x_name'].str.contains(keyword, case=False, na=False)
        results = search_df[mask]['x_name'].unique()
        
        if len(results) > 0:
            print(f"   ✅ 找到 {len(results)} 个相关节点。最匹配的前 10 个如下：")
            sorted_results = sorted(results, key=len)
            for i, res in enumerate(sorted_results[:10]):
                print(f"      [{i+1}] {res}")
        else:
            print(f"   ❌ 完全没有找到包含 '{keyword}' 的节点。")

    print("\n==================================================")
    print("💡 检索完毕。请复制最准确的名称并替换到 Step 2 中。")
    print("==================================================")

if __name__ == "__main__":
    precise_search_missed_nodes()
# Out:
# ...
# 🎯 启动未命中节点精准检索...
#
# ▶ 正在精准检索【房颤 (AFIB)】...
#    ✅ 找到 4 个相关节点。最匹配的前 10 个如下：
#       [1] familial atrial fibrillation
#       [2] atrial fibrillation (disease)
#       [3] Permanent atrial fibrillation
#       [4] Paroxysmal atrial fibrillation
#
# ▶ 正在精准检索【短暂性脑缺血 (TIA)】...
#    ✅ 找到 1 个相关节点。最匹配的前 10 个如下：
#       [1] transient ischemic attack (disease)
#
# ▶ 正在精准检索【脑外伤 (TBI)】...
#    ❌ 完全没有找到包含 'traumatic brain' 的节点。
#
# ▶ 正在精准检索【高胆固醇 (HYPERCHO)】...
#    ✅ 找到 6 个相关节点。最匹配的前 10 个如下：
#       [1] Hypercholesterolemia
#       [2] familial hypercholesterolemia
#       [3] hypercholesterolemia, autosomal dominant
#       [4] homozygous familial hypercholesterolemia
#       [5] hypercholesterolemia due to cholesterol 7alpha-hydroxylase deficiency
#       [6] hypomagnesemia, hypertension, and hypercholesterolemia, mitochondrial
#
# ▶ 正在精准检索【糖尿病 (DIABETES)】...
#    ✅ 找到 62 个相关节点。最匹配的前 10 个如下：
#       [1] Maternal diabetes
#       [2] Diabetes insipidus
#       [3] diabetes insipidus
# ...
