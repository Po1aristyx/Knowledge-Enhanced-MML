# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0

with open('NACC_normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'E:/code/NACC_nii_no/NACC_nii_no/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('NACC_ad.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/NACC_nii_ad/NACC_nii_ad/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('NACC_mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/NACC_mci/NACC_mci/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #713
print(count_no) #2116
print(count_mci) #879
# Out:
# 713
# 2116
# 879

# %%
# 基础替换字典 (请根据NACC的具体字符继续补充)
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0', 'ind': '3', 'ans': '4', 'no': '0', 'yes': '1', 'haw': '3'}

# EHR 模块 (53维): 人口学 (3-7) + 病史 (60-107)
ehr_cols = [3, 4, 5, 6, 7] + list(range(60, 108))

# BIO 模块 (43维): apoe (8) + 认知量表与问卷 (18-59)
bio_cols = [8] + list(range(18, 60))

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        # 仅提取安全的特征列
        extracted_row = [row[idx] for idx in target_cols]
        # 字典映射替换
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                # 拦截 NaN，替换为 0.0
                if math.isnan(val):
                    val = 0.0
            except ValueError:
                # 无法转换的值替换为 0.0
                val = 0.0 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# %%
# 1. 提取 BIO 数组 (真实的 47 维特征)
ad_bio_array = preprocess_data(data_ad, replace_dict, bio_cols)
normal_bio_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_bio_array = preprocess_data(data_mci, replace_dict, bio_cols)

# 2. 直接转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_bio_array).float()
normal_tensor = torch.from_numpy(normal_bio_array).float()
mci_tensor = torch.from_numpy(mci_bio_array).float()

# 3. 打印结果检查维度
print('AD_tensor shape:', ad_tensor.shape)       
print('Normal_tensor shape:', normal_tensor.shape) 
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([713, 43])
# Normal_tensor shape: torch.Size([2116, 43])
# MCI_tensor shape: torch.Size([879, 43])

# %%
# 1. 提取脱敏后的 EHR 数组 (真实的 59 维特征)
ad_ehr_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_ehr_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_ehr_data = preprocess_data(data_mci, replace_dict, ehr_cols)

# 2. 直接转换为 Tensor
ad_EHR = torch.from_numpy(ad_ehr_data).float()
normal_EHR = torch.from_numpy(normal_ehr_data).float()
mci_EHR = torch.from_numpy(mci_ehr_data).float()

# 3. 打印结果检查维度
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([713, 53])
# normal.EHR---> torch.Size([2116, 53])
# mci.EHR---> torch.Size([879, 53])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
# Out:
# Using device: cuda

# %%
import torch
import gc
from torch.utils.data import DataLoader
from tqdm import tqdm  # 引入 tqdm 库用于显示进度

# 1. 显式清理缓存，防止之前的残留占用显存
torch.cuda.empty_cache()
gc.collect()

# 2. 实例化模型，将输出维度设为64，严格匹配 Transformer 的 img_dim=64
nii = CNN_3D(num_class=64)
nii = nii.to(device)
nii.eval() # 开启评估模式，冻结网络行为

def extract_mri_features(folder_path, batch_size=16):
    # 注意：这里将默认 batch_size 改为 4，防止 NACC 的 3D 图像导致 OOM
    dataset = NiiDataset(folder_path)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_outputs = []
    
    # 关闭梯度计算，节省显存并加快提取速度
    with torch.no_grad():
        # 使用 tqdm 包装 dataloader，实时打印当前文件夹的提取进度
        for batch_idx, batch_data in enumerate(tqdm(dataloader, desc="Extracting features")):
            batch_data = batch_data.to(device)
            output = nii(batch_data)
            # 提取后立即 detach 并转回 CPU，防止 GPU 显存堆积
            all_outputs.append(output.detach().cpu())
            
    # 每次提取完一个类别后，显式清理局部变量和显存
    del dataset, dataloader
    torch.cuda.empty_cache()
    gc.collect()
            
    return torch.cat(all_outputs, dim=0)

# NACC 图像数据路径
all_ad = 'E:/code/NACC_nii_ad/NACC_nii_ad/'
all_normal = 'E:/code/NACC_nii_no/NACC_nii_no/'
all_mci = 'E:/code/NACC_mci/NACC_mci/'

# 3. 模块化调用提取特征
ad_output = extract_mri_features(all_ad, batch_size=4)
print('ad nii shape--->', ad_output.shape)

normal_output = extract_mri_features(all_normal, batch_size=4)
print('normal nii shape--->', normal_output.shape)

mci_output = extract_mri_features(all_mci, batch_size=4)
print('mci nii shape--->', mci_output.shape)
# Out:
# Extracting features: 100%|██████████| 179/179 [00:32<00:00,  5.44it/s]
# ad nii shape---> torch.Size([713, 64])
# Extracting features: 100%|██████████| 529/529 [01:30<00:00,  5.85it/s]
# normal nii shape---> torch.Size([2116, 64])
# Extracting features: 100%|██████████| 220/220 [00:37<00:00,  5.81it/s]
# mci nii shape---> torch.Size([879, 64])

# %%
import numpy as np
import torch
import pandas as pd
import json

# 保持你的路径配置不变
ENTITY_EMB_NPY = "NACC-DementiaHKG-Embeddings.npy"
ENTITY2ID_FILE = "NACC-DementiaHKG-Entity2ID.json"
PATIENT_QUERY_DICT = "NACC-DementiaHKG-Entities.json"

with open(ENTITY2ID_FILE, 'r', encoding='utf-8') as f:
    entity2id = json.load(f)

with open(PATIENT_QUERY_DICT, 'r', encoding='utf-8') as f:
    patient_entities = json.load(f)

emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
embed_dim = emb.shape[1] 
max_seq_len = 45 

def get_patient_embedding_seq(filename: str):
    filename = str(filename).strip()
    patient_data = patient_entities.get(filename, {})
    active_nodes = patient_data.get("input_nodes", [])
    
    vecs = []
    pad_masks = []
    
    # 构造固定长度为45的序列与对应的布尔掩码
    for i in range(max_seq_len):
        if i < len(active_nodes):
            node = active_nodes[i]
            if node != "[PAD]" and node in entity2id:
                vecs.append(emb[entity2id[node]])
                pad_masks.append(False) 
            else:
                vecs.append(torch.zeros(embed_dim))
                pad_masks.append(True) 
        else:
            vecs.append(torch.zeros(embed_dim))
            pad_masks.append(True)
            
    # 返回知识序列矩阵和用于PyTorch注意力的掩码
    return torch.stack(vecs), torch.tensor(pad_masks, dtype=torch.bool)

def process_and_verify_seq(df, cohort_name):
    seq_tensors = []
    mask_tensors = []
    valid_count = 0
    
    for _, r in df.iterrows():
        seq_tensor, mask_tensor = get_patient_embedding_seq(r['filename'])
        seq_tensors.append(seq_tensor)
        mask_tensors.append(mask_tensor)
        
        # 验证是否包含至少一个有效节点（掩码中存在False）
        if not torch.all(mask_tensor):
            valid_count += 1
            
    stacked_seq = torch.stack(seq_tensors)
    stacked_mask = torch.stack(mask_tensors)
    
    print(f"[{cohort_name}] 总样本数: {len(df)} | 成功注入KG先验序列的样本数: {valid_count}")
    return stacked_seq, stacked_mask

# 执行数据提取
print("开始提取完整知识序列与注意力掩码...")
ad_transe_seq, ad_transe_mask = process_and_verify_seq(pd.read_csv('NACC_ad.csv'), "AD")
mci_transe_seq, mci_transe_mask = process_and_verify_seq(pd.read_csv('NACC_mci.csv'), "MCI")
nc_transe_seq, nc_transe_mask = process_and_verify_seq(pd.read_csv('NACC_normal.csv'), "NC")

print("最终生成的知识序列 Shapes:", ad_transe_seq.shape, mci_transe_seq.shape, nc_transe_seq.shape)
print("最终生成的掩码张量 Shapes:", ad_transe_mask.shape, mci_transe_mask.shape, nc_transe_mask.shape)
# Out:
# 开始提取完整知识序列与注意力掩码...
# [AD] 总样本数: 713 | 成功注入KG先验序列的样本数: 709
# [MCI] 总样本数: 879 | 成功注入KG先验序列的样本数: 872
# [NC] 总样本数: 2116 | 成功注入KG先验序列的样本数: 1802
# 最终生成的知识序列 Shapes: torch.Size([713, 45, 128]) torch.Size([879, 45, 128]) torch.Size([2116, 45, 128])
# 最终生成的掩码张量 Shapes: torch.Size([713, 45]) torch.Size([879, 45]) torch.Size([2116, 45])

# %%
# 第一步：合并原有的多模态特征 (EHR + IMG + BIO)
features_ad = torch.cat([ad_EHR, ad_output.cpu(), ad_tensor], dim=1)
features_mci = torch.cat([mci_EHR, mci_output.cpu(), mci_tensor], dim=1)
features_normal = torch.cat([normal_EHR, normal_output.cpu(), normal_tensor], dim=1)

# 第二步：沿着批次维度(dim=0)纵向合并所有样本的特征
features = torch.cat([features_ad, features_mci, features_normal], dim=0).float()

# 第三步：纵向合并上一步提取的所有样本的知识序列矩阵
kg_seq = torch.cat([ad_transe_seq, mci_transe_seq, nc_transe_seq], dim=0).float()

# 第四步：纵向合并对应的知识掩码矩阵
kg_mask = torch.cat([ad_transe_mask, mci_transe_mask, nc_transe_mask], dim=0).bool()

# 第五步：生成类别标签
y_ad = torch.ones(len(features_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(features_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(features_normal)) * 0  # NC 类别标签为 0

# 分类任务的标签通常建议使用 long 类型
y = torch.cat([y_ad, y_mci, y_normal], dim=0).long() 

print("多模态特征 (features) 维度:", features.shape)
print("知识序列 (kg_seq) 维度:", kg_seq.shape)
print("注意力掩码 (kg_mask) 维度:", kg_mask.shape)
print("标签 (y) 维度:", y.shape)
# Out:
# 多模态特征 (features) 维度: torch.Size([3708, 160])
# 知识序列 (kg_seq) 维度: torch.Size([3708, 45, 128])
# 注意力掩码 (kg_mask) 维度: torch.Size([3708, 45])
# 标签 (y) 维度: torch.Size([3708])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.impute import SimpleImputer
import torch
# 1. 正常的划分数据集：同时切分特征(features), 图谱序列(kg_seq), 掩码(kg_mask) 和 标签(y)
# ★★★ 修复 NaN 报错的核心代码：防止全填充序列导致 Attention Softmax 除零崩溃 ★★★
# 找到那些掩码一整行全为 True 的样本（完全没有图谱节点的健康人）
all_padded_idx = kg_mask.all(dim=1)
# 强行把这些样本的第0个位置的掩码设为 False，使其能够去关注一个全零的 Padding 向量
kg_mask[all_padded_idx, 0] = False

X_train, X_test, seq_train, seq_test, mask_train, mask_test, y_train, y_test = train_test_split(
    features.detach().numpy(), 
    kg_seq.detach().numpy(), 
    kg_mask.detach().numpy(), 
    y.numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)


X_train, X_val, seq_train, seq_val, mask_train, mask_val, y_train, y_val = train_test_split(
    X_train, seq_train, mask_train, y_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)

# ----------------- 缺失值填充与归一化模块 -----------------
# 2. 初始化填充器和标准化器
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

# 3. 仅在训练集的“多模态特征(X)”上进行 fit_transform，严防数据泄露。图谱序列和掩码无需处理。
X_train = imputer.fit_transform(X_train)
X_train = scaler.fit_transform(X_train)

# 4. 在验证集和测试集上仅进行 transform
X_val = imputer.transform(X_val)
X_val = scaler.transform(X_val)

X_test = imputer.transform(X_test)
X_test = scaler.transform(X_test)
# ----------------------------------------------------

# 5. 转为 Tensor 并构建 DataLoader
X_train_tensor = torch.FloatTensor(X_train).to(device)
seq_train_tensor = torch.FloatTensor(seq_train).to(device)
mask_train_tensor = torch.BoolTensor(mask_train).to(device) # 注意掩码用 BoolTensor
y_train_tensor = torch.LongTensor(y_train).to(device)  

X_val_tensor = torch.FloatTensor(X_val).to(device)
seq_val_tensor = torch.FloatTensor(seq_val).to(device)
mask_val_tensor = torch.BoolTensor(mask_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
seq_test_tensor = torch.FloatTensor(seq_test).to(device)
mask_test_tensor = torch.BoolTensor(mask_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)

# 将 4 个张量打包进入 Dataset
train_dataset = TensorDataset(X_train_tensor, seq_train_tensor, mask_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, seq_val_tensor, mask_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, seq_test_tensor, mask_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    # 接收新增的 mask 张量
    for inputs, transe_embed, mask, labels in loader:
        inputs = inputs.to(device)
        transe_embed = transe_embed.to(device)
        mask = mask.to(device)
        labels = labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        # 将 mask 传入模型
        outputs = model(inputs, transe_embed, mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        # 接收新增的 mask 张量
        for inputs, transe_embed, mask, labels in loader:
            inputs = inputs.to(device)
            transe_embed = transe_embed.to(device)
            mask = mask.to(device)
            labels = labels.to(device)
            labels = labels.long()
            
            # 将 mask 传入模型
            outputs = model(inputs, transe_embed, mask)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
class KGMultiModalTransformer(nn.Module):
    """
    诊断知识引导的多模态协同交互网络 (Knowledge-Guided Multimodal Synergistic Interaction)
    NACC数据集专属终极版本：解耦知识投影 + 解耦交叉注意力 + 动态掩码屏蔽
    """
    def __init__(self, ehr_dim=53, img_dim=64, bio_dim=43, embed_dim=128, num_heads=4, transe_embed_dim=128):
        super().__init__()
        
        self.ehr_dim = ehr_dim
        self.img_dim = img_dim
        self.bio_dim = bio_dim
        
        # ==========================================
        # 1. 跨模态解耦编码器 (保留你的加宽设计)
        # ==========================================
        self.ehr_encoder = nn.Sequential(
            nn.Linear(ehr_dim, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, embed_dim),
            nn.BatchNorm1d(embed_dim),
            nn.ReLU()
        )
        
        self.img_encoder = nn.Sequential(
            nn.Linear(img_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, embed_dim),
            nn.BatchNorm1d(embed_dim),
            nn.ReLU()
        )
        
        self.bio_encoder = nn.Sequential(
            nn.Linear(bio_dim, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, embed_dim),
            nn.BatchNorm1d(embed_dim),
            nn.ReLU()
        )

        # ==========================================
        # 2. 模态专属的知识流形投影层 (引入我的解耦设计)
        # 作用：让 128 维的 KG 向量独立平滑过渡到各自的语义空间
        # ==========================================
        self.ehr_kg_proj = nn.Sequential(
            nn.Linear(transe_embed_dim, transe_embed_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(transe_embed_dim, embed_dim)
        )
        
        self.bio_kg_proj = nn.Sequential(
            nn.Linear(transe_embed_dim, transe_embed_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(transe_embed_dim, embed_dim)
        )
        
        self.img_kg_proj = nn.Sequential(
            nn.Linear(transe_embed_dim, transe_embed_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(transe_embed_dim, embed_dim)
        )

        # ==========================================
        # 3. 模态感知知识检索引擎
        # ==========================================
        self.ehr_kg_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)
        self.bio_kg_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)
        self.img_kg_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)

        self.norm_ehr_kg = nn.LayerNorm(embed_dim)
        self.norm_bio_kg = nn.LayerNorm(embed_dim)
        self.norm_img_kg = nn.LayerNorm(embed_dim)

        # ==========================================
        # 4. 线性投影层
        # ==========================================
        self.bio_q = nn.Linear(embed_dim, embed_dim)
        self.bio_k = nn.Linear(embed_dim, embed_dim)
        self.bio_v = nn.Linear(embed_dim, embed_dim)

        self.ehr_q = nn.Linear(embed_dim, embed_dim)
        self.ehr_k = nn.Linear(embed_dim, embed_dim)
        self.ehr_v = nn.Linear(embed_dim, embed_dim)

        self.img_q = nn.Linear(embed_dim, embed_dim)

        # ==========================================
        # 5. 交叉注意力引擎与降维模块 (保留你的独立参数设计)
        # ==========================================
        self.bio_ehr_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)
        self.ehr_bio_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)
        self.img_fusion_attn = nn.MultiheadAttention(embed_dim, num_heads, batch_first=True, dropout=0.2)
        
        self.norm_bio_ehr = nn.LayerNorm(embed_dim)
        self.norm_ehr_bio = nn.LayerNorm(embed_dim)
        self.norm_img = nn.LayerNorm(embed_dim)

        self.ab_proj = nn.Sequential(
            nn.Linear(2 * embed_dim, embed_dim),
            nn.ReLU(),
            nn.Dropout(0.3)
        )

        # ==========================================
        # 6. 最终决策融合层 (保留你的 128 维宽层)
        # ==========================================
        self.fusion = nn.Sequential(
            nn.Linear(embed_dim * 2, 128), 
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3), 
            nn.Linear(128, 3) 
        )

    def forward(self, x, kg_seq, kg_mask):
        # 修复 PyTorch Mask 逻辑
        kg_mask_pt = (kg_mask == 0).bool()

        # 切片分离
        ehr_end = self.ehr_dim
        img_end = ehr_end + self.img_dim
        
        ehr = x[:, :ehr_end]                          
        img = x[:, ehr_end:img_end]                  
        bio = x[:, img_end:img_end+self.bio_dim]     

        ehr_feat = self.ehr_encoder(ehr).unsqueeze(1) 
        img_feat = self.img_encoder(img).unsqueeze(1) 
        bio_feat = self.bio_encoder(bio).unsqueeze(1) 

        # 使用模态专属的图谱投影
        kg_feat_ehr = self.ehr_kg_proj(kg_seq)
        kg_feat_bio = self.bio_kg_proj(kg_seq)
        kg_feat_img = self.img_kg_proj(kg_seq)

       # 4. 知识检索
        # 🚨【修改点】直接传入 kg_mask
        ehr_kg_out, _ = self.ehr_kg_attn(query=ehr_feat, key=kg_feat_ehr, value=kg_feat_ehr, key_padding_mask=kg_mask)
        bio_kg_out, _ = self.bio_kg_attn(query=bio_feat, key=kg_feat_bio, value=kg_feat_bio, key_padding_mask=kg_mask)
        img_kg_out, _ = self.img_kg_attn(query=img_feat, key=kg_feat_img, value=kg_feat_img, key_padding_mask=kg_mask)

        ehr_enhanced = self.norm_ehr_kg(ehr_feat + ehr_kg_out)
        bio_enhanced = self.norm_bio_kg(bio_feat + bio_kg_out)
        img_enhanced = self.norm_img_kg(img_feat + img_kg_out)

        # 交叉注意力准备
        Qa, Ka, Va = self.bio_q(bio_enhanced), self.bio_k(bio_enhanced), self.bio_v(bio_enhanced)
        Qb, Kb, Vb = self.ehr_q(ehr_enhanced), self.ehr_k(ehr_enhanced), self.ehr_v(ehr_enhanced)

        # 独立底层融合
        bio_ehr_out_attn, _ = self.bio_ehr_attn(query=Qa, key=Kb, value=Vb) 
        ehr_bio_out_attn, _ = self.ehr_bio_attn(query=Qb, key=Ka, value=Va) 

        bio_ehr_out = self.norm_bio_ehr(bio_enhanced + bio_ehr_out_attn)
        ehr_bio_out = self.norm_ehr_bio(ehr_enhanced + ehr_bio_out_attn)

        ab_combined = torch.cat([bio_ehr_out, ehr_bio_out], dim=1)        
        ab_combined = ab_combined.view(ab_combined.size(0), -1)           
        ab_combined = self.ab_proj(ab_combined).unsqueeze(1)              
        
        # 独立高阶影像融合
        Qc = self.img_q(img_enhanced)  
        img_ab_out_attn, _ = self.img_fusion_attn(query=Qc, key=ab_combined, value=ab_combined) 
        img_out = self.norm_img(img_enhanced + img_ab_out_attn)               

        final_combined = torch.cat(
            [
                ab_combined.squeeze(1),   
                img_out.squeeze(1)        
            ],
            dim=1
        ) 
        
        return self.fusion(final_combined)

# %%
embed_dim = 128
transe_embed_dim = 128
num_epochs = 200
batch_size = 32
learning_rate = 1e-5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
weight_decay = 1e-3

model = KGMultiModalTransformer(embed_dim=embed_dim, transe_embed_dim=transe_embed_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate,weight_decay=weight_decay)

train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    if epoch % 10 == 0: print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# Epoch 1/200, Train Loss: 1.1415, Train AUC: 0.5311  test Loss: 1.0556, test AUC: 0.6316
# Epoch 2/200, Train Loss: 1.1042, Train AUC: 0.5567  test Loss: 0.9422, test AUC: 0.7164
# Epoch 3/200, Train Loss: 1.0583, Train AUC: 0.6100  test Loss: 0.9314, test AUC: 0.7670
# Epoch 4/200, Train Loss: 1.0168, Train AUC: 0.6489  test Loss: 0.8817, test AUC: 0.7759
# Epoch 5/200, Train Loss: 0.9928, Train AUC: 0.6625  test Loss: 0.8428, test AUC: 0.8298
# Epoch 6/200, Train Loss: 0.9537, Train AUC: 0.7087  test Loss: 0.8060, test AUC: 0.8416
# Epoch 7/200, Train Loss: 0.9174, Train AUC: 0.7345  test Loss: 0.7555, test AUC: 0.8478
# Epoch 8/200, Train Loss: 0.9019, Train AUC: 0.7400  test Loss: 0.7602, test AUC: 0.8733
# Epoch 9/200, Train Loss: 0.8654, Train AUC: 0.7599  test Loss: 0.7107, test AUC: 0.8706
# Epoch 10/200, Train Loss: 0.8221, Train AUC: 0.7934  test Loss: 0.6859, test AUC: 0.8884
# Epoch 11/200, Train Loss: 0.7998, Train AUC: 0.8004  test Loss: 0.6497, test AUC: 0.8921
# Epoch 12/200, Train Loss: 0.7655, Train AUC: 0.8228  test Loss: 0.6297, test AUC: 0.8923
# Epoch 13/200, Train Loss: 0.7635, Train AUC: 0.8121  test Loss: 0.6230, test AUC: 0.8989
# Epoch 14/200, Train Loss: 0.7396, Train AUC: 0.8358  test Loss: 0.5832, test AUC: 0.8971
# Epoch 15/200, Train Loss: 0.7047, Train AUC: 0.8465  test Loss: 0.5840, test AUC: 0.9049
# Epoch 16/200, Train Loss: 0.7037, Train AUC: 0.8410  test Loss: 0.5805, test AUC: 0.9068
# Epoch 17/200, Train Loss: 0.6917, Train AUC: 0.8476  test Loss: 0.5516, test AUC: 0.8973
# Epoch 18/200, Train Loss: 0.6737, Train AUC: 0.8514  test Loss: 0.5359, test AUC: 0.9012
# Epoch 19/200, Train Loss: 0.6685, Train AUC: 0.8584  test Loss: 0.5363, test AUC: 0.9047
# Epoch 20/200, Train Loss: 0.6506, Train AUC: 0.8617  test Loss: 0.5226, test AUC: 0.9013
# Epoch 21/200, Train Loss: 0.6263, Train AUC: 0.8747  test Loss: 0.5190, test AUC: 0.9016
# Epoch 22/200, Train Loss: 0.6374, Train AUC: 0.8691  test Loss: 0.5313, test AUC: 0.9086
# Epoch 23/200, Train Loss: 0.6299, Train AUC: 0.8661  test Loss: 0.5061, test AUC: 0.9033
# Epoch 24/200, Train Loss: 0.6361, Train AUC: 0.8658  test Loss: 0.5096, test AUC: 0.9060
# Epoch 25/200, Train Loss: 0.6045, Train AUC: 0.8774  test Loss: 0.5084, test AUC: 0.9045
# Epoch 26/200, Train Loss: 0.6058, Train AUC: 0.8782  test Loss: 0.4971, test AUC: 0.8983
# Epoch 27/200, Train Loss: 0.6041, Train AUC: 0.8794  test Loss: 0.4992, test AUC: 0.9060
# Epoch 28/200, Train Loss: 0.5914, Train AUC: 0.8835  test Loss: 0.4925, test AUC: 0.9055
# Epoch 29/200, Train Loss: 0.5988, Train AUC: 0.8746  test Loss: 0.4941, test AUC: 0.9048
# Epoch 30/200, Train Loss: 0.5971, Train AUC: 0.8798  test Loss: 0.4881, test AUC: 0.9015
# Epoch 31/200, Train Loss: 0.5729, Train AUC: 0.8912  test Loss: 0.4891, test AUC: 0.9046
# Epoch 32/200, Train Loss: 0.5696, Train AUC: 0.8878  test Loss: 0.4920, test AUC: 0.9119
# Epoch 33/200, Train Loss: 0.5667, Train AUC: 0.8895  test Loss: 0.4865, test AUC: 0.9105
# Epoch 34/200, Train Loss: 0.5688, Train AUC: 0.8922  test Loss: 0.4787, test AUC: 0.9083
# Epoch 35/200, Train Loss: 0.5736, Train AUC: 0.8844  test Loss: 0.4787, test AUC: 0.9021
# Epoch 36/200, Train Loss: 0.5634, Train AUC: 0.8887  test Loss: 0.4799, test AUC: 0.9069
# Epoch 37/200, Train Loss: 0.5623, Train AUC: 0.8913  test Loss: 0.4773, test AUC: 0.9085
# Epoch 38/200, Train Loss: 0.5724, Train AUC: 0.8890  test Loss: 0.4795, test AUC: 0.9145
# Epoch 39/200, Train Loss: 0.5465, Train AUC: 0.8952  test Loss: 0.4723, test AUC: 0.9096
# Epoch 40/200, Train Loss: 0.5595, Train AUC: 0.8937  test Loss: 0.4711, test AUC: 0.9073
# Epoch 41/200, Train Loss: 0.5422, Train AUC: 0.8973  test Loss: 0.4666, test AUC: 0.9069
# Epoch 42/200, Train Loss: 0.5639, Train AUC: 0.8872  test Loss: 0.4694, test AUC: 0.9079
# Epoch 43/200, Train Loss: 0.5497, Train AUC: 0.8917  test Loss: 0.4659, test AUC: 0.9133
# Epoch 44/200, Train Loss: 0.5583, Train AUC: 0.8949  test Loss: 0.4838, test AUC: 0.8924
# Epoch 45/200, Train Loss: 0.5284, Train AUC: 0.9024  test Loss: 0.4645, test AUC: 0.9092
# Epoch 46/200, Train Loss: 0.5244, Train AUC: 0.9028  test Loss: 0.4620, test AUC: 0.9099
# Epoch 47/200, Train Loss: 0.5447, Train AUC: 0.8936  test Loss: 0.4626, test AUC: 0.9132
# Epoch 48/200, Train Loss: 0.5300, Train AUC: 0.9014  test Loss: 0.4701, test AUC: 0.9007
# Epoch 49/200, Train Loss: 0.5451, Train AUC: 0.8978  test Loss: 0.4753, test AUC: 0.8974
# Epoch 50/200, Train Loss: 0.5296, Train AUC: 0.9001  test Loss: 0.4601, test AUC: 0.9114
# Epoch 51/200, Train Loss: 0.5161, Train AUC: 0.9067  test Loss: 0.4610, test AUC: 0.9085
# Epoch 52/200, Train Loss: 0.5247, Train AUC: 0.9007  test Loss: 0.4594, test AUC: 0.9138
# Epoch 53/200, Train Loss: 0.5177, Train AUC: 0.9031  test Loss: 0.4601, test AUC: 0.9153
# Epoch 54/200, Train Loss: 0.5025, Train AUC: 0.9090  test Loss: 0.4588, test AUC: 0.9083
# Epoch 55/200, Train Loss: 0.5173, Train AUC: 0.9062  test Loss: 0.4610, test AUC: 0.9165
# Epoch 56/200, Train Loss: 0.5098, Train AUC: 0.9085  test Loss: 0.4577, test AUC: 0.9148
# Epoch 57/200, Train Loss: 0.5356, Train AUC: 0.8956  test Loss: 0.4576, test AUC: 0.9136
# Epoch 58/200, Train Loss: 0.5369, Train AUC: 0.8990  test Loss: 0.4625, test AUC: 0.9084
# Epoch 59/200, Train Loss: 0.5205, Train AUC: 0.9040  test Loss: 0.4629, test AUC: 0.9020
# Epoch 60/200, Train Loss: 0.5158, Train AUC: 0.9059  test Loss: 0.4655, test AUC: 0.9017
# Epoch 61/200, Train Loss: 0.5254, Train AUC: 0.9012  test Loss: 0.4564, test AUC: 0.9097
# Epoch 62/200, Train Loss: 0.5196, Train AUC: 0.9029  test Loss: 0.4583, test AUC: 0.9144
# Epoch 63/200, Train Loss: 0.5030, Train AUC: 0.9082  test Loss: 0.4537, test AUC: 0.9142
# Epoch 64/200, Train Loss: 0.5256, Train AUC: 0.9066  test Loss: 0.4719, test AUC: 0.8976
# Epoch 65/200, Train Loss: 0.4959, Train AUC: 0.9108  test Loss: 0.4560, test AUC: 0.9107
# Epoch 66/200, Train Loss: 0.4999, Train AUC: 0.9095  test Loss: 0.4580, test AUC: 0.9163
# Epoch 67/200, Train Loss: 0.5096, Train AUC: 0.9043  test Loss: 0.4705, test AUC: 0.8983
# Epoch 68/200, Train Loss: 0.5152, Train AUC: 0.9012  test Loss: 0.4594, test AUC: 0.9077
# Epoch 69/200, Train Loss: 0.5054, Train AUC: 0.9058  test Loss: 0.4602, test AUC: 0.9036
# Epoch 70/200, Train Loss: 0.4982, Train AUC: 0.9092  test Loss: 0.4662, test AUC: 0.8987
# Epoch 71/200, Train Loss: 0.4963, Train AUC: 0.9094  test Loss: 0.4539, test AUC: 0.9126
# Epoch 72/200, Train Loss: 0.5138, Train AUC: 0.9047  test Loss: 0.4576, test AUC: 0.9118
# Epoch 73/200, Train Loss: 0.4972, Train AUC: 0.9111  test Loss: 0.4554, test AUC: 0.9095
# Epoch 74/200, Train Loss: 0.5016, Train AUC: 0.9081  test Loss: 0.4532, test AUC: 0.9096
# Epoch 75/200, Train Loss: 0.5072, Train AUC: 0.9078  test Loss: 0.4529, test AUC: 0.9119
# Epoch 76/200, Train Loss: 0.4853, Train AUC: 0.9142  test Loss: 0.4530, test AUC: 0.9098
# Epoch 77/200, Train Loss: 0.5271, Train AUC: 0.9055  test Loss: 0.4558, test AUC: 0.9073
# Epoch 78/200, Train Loss: 0.5026, Train AUC: 0.9083  test Loss: 0.4524, test AUC: 0.9106
# Epoch 79/200, Train Loss: 0.4995, Train AUC: 0.9125  test Loss: 0.4692, test AUC: 0.8980
# Epoch 80/200, Train Loss: 0.4871, Train AUC: 0.9113  test Loss: 0.4517, test AUC: 0.9137
# Epoch 81/200, Train Loss: 0.5005, Train AUC: 0.9097  test Loss: 0.4703, test AUC: 0.8979
# Epoch 82/200, Train Loss: 0.4823, Train AUC: 0.9149  test Loss: 0.4601, test AUC: 0.9028
# Epoch 83/200, Train Loss: 0.4876, Train AUC: 0.9135  test Loss: 0.4522, test AUC: 0.9106
# Epoch 84/200, Train Loss: 0.4827, Train AUC: 0.9122  test Loss: 0.4517, test AUC: 0.9113
# Epoch 85/200, Train Loss: 0.4864, Train AUC: 0.9123  test Loss: 0.4536, test AUC: 0.9119
# Epoch 86/200, Train Loss: 0.5007, Train AUC: 0.9076  test Loss: 0.4534, test AUC: 0.9138
# Epoch 87/200, Train Loss: 0.4899, Train AUC: 0.9161  test Loss: 0.4521, test AUC: 0.9099
# Epoch 88/200, Train Loss: 0.5078, Train AUC: 0.9126  test Loss: 0.4529, test AUC: 0.9115
# Epoch 89/200, Train Loss: 0.4863, Train AUC: 0.9117  test Loss: 0.4490, test AUC: 0.9166
# Epoch 90/200, Train Loss: 0.4832, Train AUC: 0.9136  test Loss: 0.4510, test AUC: 0.9162
# Epoch 91/200, Train Loss: 0.4750, Train AUC: 0.9175  test Loss: 0.4548, test AUC: 0.9062
# Epoch 92/200, Train Loss: 0.4655, Train AUC: 0.9202  test Loss: 0.4517, test AUC: 0.9100
# Epoch 93/200, Train Loss: 0.4926, Train AUC: 0.9139  test Loss: 0.4509, test AUC: 0.9104
# Epoch 94/200, Train Loss: 0.4974, Train AUC: 0.9152  test Loss: 0.4494, test AUC: 0.9144
# Epoch 95/200, Train Loss: 0.4788, Train AUC: 0.9144  test Loss: 0.4501, test AUC: 0.9107
# Epoch 96/200, Train Loss: 0.4682, Train AUC: 0.9178  test Loss: 0.4479, test AUC: 0.9154
# Epoch 97/200, Train Loss: 0.4799, Train AUC: 0.9186  test Loss: 0.4471, test AUC: 0.9141
# Epoch 98/200, Train Loss: 0.4966, Train AUC: 0.9104  test Loss: 0.4572, test AUC: 0.9065
# Epoch 99/200, Train Loss: 0.4745, Train AUC: 0.9166  test Loss: 0.4534, test AUC: 0.9089
# Epoch 100/200, Train Loss: 0.4780, Train AUC: 0.9185  test Loss: 0.4530, test AUC: 0.9069
# Epoch 101/200, Train Loss: 0.4945, Train AUC: 0.9116  test Loss: 0.4519, test AUC: 0.9151
# Epoch 102/200, Train Loss: 0.4850, Train AUC: 0.9160  test Loss: 0.4547, test AUC: 0.9150
# Epoch 103/200, Train Loss: 0.4777, Train AUC: 0.9156  test Loss: 0.4468, test AUC: 0.9108
# Epoch 104/200, Train Loss: 0.4701, Train AUC: 0.9181  test Loss: 0.4473, test AUC: 0.9117
# Epoch 105/200, Train Loss: 0.4780, Train AUC: 0.9146  test Loss: 0.4514, test AUC: 0.9088
# Epoch 106/200, Train Loss: 0.4594, Train AUC: 0.9222  test Loss: 0.4468, test AUC: 0.9123
# Epoch 107/200, Train Loss: 0.4765, Train AUC: 0.9173  test Loss: 0.4518, test AUC: 0.9080
# Epoch 108/200, Train Loss: 0.4729, Train AUC: 0.9190  test Loss: 0.4509, test AUC: 0.9142
# Epoch 109/200, Train Loss: 0.4769, Train AUC: 0.9204  test Loss: 0.4601, test AUC: 0.9026
# Epoch 110/200, Train Loss: 0.4664, Train AUC: 0.9206  test Loss: 0.4514, test AUC: 0.9120
# Epoch 111/200, Train Loss: 0.4628, Train AUC: 0.9207  test Loss: 0.4517, test AUC: 0.9080
# Epoch 112/200, Train Loss: 0.4645, Train AUC: 0.9219  test Loss: 0.4510, test AUC: 0.9111
# Epoch 113/200, Train Loss: 0.4678, Train AUC: 0.9176  test Loss: 0.4495, test AUC: 0.9120
# Epoch 114/200, Train Loss: 0.4742, Train AUC: 0.9190  test Loss: 0.4521, test AUC: 0.9102
# Epoch 115/200, Train Loss: 0.4718, Train AUC: 0.9180  test Loss: 0.4517, test AUC: 0.9117
# Epoch 116/200, Train Loss: 0.4589, Train AUC: 0.9241  test Loss: 0.4505, test AUC: 0.9140
# Epoch 117/200, Train Loss: 0.4685, Train AUC: 0.9219  test Loss: 0.4483, test AUC: 0.9103
# Epoch 118/200, Train Loss: 0.4479, Train AUC: 0.9255  test Loss: 0.4540, test AUC: 0.9108
# Epoch 119/200, Train Loss: 0.4446, Train AUC: 0.9280  test Loss: 0.4564, test AUC: 0.9116
# Epoch 120/200, Train Loss: 0.4556, Train AUC: 0.9220  test Loss: 0.4465, test AUC: 0.9123
# Epoch 121/200, Train Loss: 0.4690, Train AUC: 0.9196  test Loss: 0.4522, test AUC: 0.9090
# Epoch 122/200, Train Loss: 0.4661, Train AUC: 0.9195  test Loss: 0.4488, test AUC: 0.9125
# Epoch 123/200, Train Loss: 0.4540, Train AUC: 0.9266  test Loss: 0.4569, test AUC: 0.9069
# Epoch 124/200, Train Loss: 0.4572, Train AUC: 0.9217  test Loss: 0.4527, test AUC: 0.9155
# Epoch 125/200, Train Loss: 0.4451, Train AUC: 0.9268  test Loss: 0.4555, test AUC: 0.9120
# Epoch 126/200, Train Loss: 0.4470, Train AUC: 0.9253  test Loss: 0.4508, test AUC: 0.9088
# Epoch 127/200, Train Loss: 0.4554, Train AUC: 0.9216  test Loss: 0.4512, test AUC: 0.9088
# Epoch 128/200, Train Loss: 0.4604, Train AUC: 0.9248  test Loss: 0.4483, test AUC: 0.9151
# Epoch 129/200, Train Loss: 0.4458, Train AUC: 0.9281  test Loss: 0.4543, test AUC: 0.9065
# Epoch 130/200, Train Loss: 0.4467, Train AUC: 0.9270  test Loss: 0.4520, test AUC: 0.9165
# Epoch 131/200, Train Loss: 0.4505, Train AUC: 0.9232  test Loss: 0.4539, test AUC: 0.9079
# Epoch 132/200, Train Loss: 0.4453, Train AUC: 0.9256  test Loss: 0.4487, test AUC: 0.9127
# Epoch 133/200, Train Loss: 0.4402, Train AUC: 0.9275  test Loss: 0.4511, test AUC: 0.9091
# Epoch 134/200, Train Loss: 0.4599, Train AUC: 0.9209  test Loss: 0.4495, test AUC: 0.9096
# Epoch 135/200, Train Loss: 0.4527, Train AUC: 0.9258  test Loss: 0.4487, test AUC: 0.9114
# Epoch 136/200, Train Loss: 0.4725, Train AUC: 0.9225  test Loss: 0.4506, test AUC: 0.9112
# Epoch 137/200, Train Loss: 0.4558, Train AUC: 0.9222  test Loss: 0.4572, test AUC: 0.9170
# Epoch 138/200, Train Loss: 0.4522, Train AUC: 0.9229  test Loss: 0.4561, test AUC: 0.9161
# Epoch 139/200, Train Loss: 0.4538, Train AUC: 0.9238  test Loss: 0.4488, test AUC: 0.9147
# Epoch 140/200, Train Loss: 0.4557, Train AUC: 0.9239  test Loss: 0.4499, test AUC: 0.9140
# Epoch 141/200, Train Loss: 0.4435, Train AUC: 0.9274  test Loss: 0.4499, test AUC: 0.9116
# Epoch 142/200, Train Loss: 0.4500, Train AUC: 0.9240  test Loss: 0.4454, test AUC: 0.9145
# Epoch 143/200, Train Loss: 0.4356, Train AUC: 0.9303  test Loss: 0.4515, test AUC: 0.9138
# Epoch 144/200, Train Loss: 0.4492, Train AUC: 0.9291  test Loss: 0.4545, test AUC: 0.9158
# Epoch 145/200, Train Loss: 0.4380, Train AUC: 0.9306  test Loss: 0.4576, test AUC: 0.9063
# Epoch 146/200, Train Loss: 0.4356, Train AUC: 0.9290  test Loss: 0.4526, test AUC: 0.9074
# Epoch 147/200, Train Loss: 0.4538, Train AUC: 0.9269  test Loss: 0.4494, test AUC: 0.9112
# Epoch 148/200, Train Loss: 0.4325, Train AUC: 0.9307  test Loss: 0.4491, test AUC: 0.9133
# Epoch 149/200, Train Loss: 0.4328, Train AUC: 0.9323  test Loss: 0.4498, test AUC: 0.9090
# Epoch 150/200, Train Loss: 0.4240, Train AUC: 0.9336  test Loss: 0.4485, test AUC: 0.9162
# Epoch 151/200, Train Loss: 0.4448, Train AUC: 0.9290  test Loss: 0.4459, test AUC: 0.9163
# Epoch 152/200, Train Loss: 0.4586, Train AUC: 0.9251  test Loss: 0.4532, test AUC: 0.9092
# Epoch 153/200, Train Loss: 0.4433, Train AUC: 0.9270  test Loss: 0.4575, test AUC: 0.9061
# Epoch 154/200, Train Loss: 0.4271, Train AUC: 0.9341  test Loss: 0.4526, test AUC: 0.9158
# Epoch 155/200, Train Loss: 0.4321, Train AUC: 0.9296  test Loss: 0.4477, test AUC: 0.9092
# Epoch 156/200, Train Loss: 0.4391, Train AUC: 0.9268  test Loss: 0.4495, test AUC: 0.9121
# Epoch 157/200, Train Loss: 0.4619, Train AUC: 0.9218  test Loss: 0.4537, test AUC: 0.9120
# Epoch 158/200, Train Loss: 0.4633, Train AUC: 0.9238  test Loss: 0.4505, test AUC: 0.9112
# Epoch 159/200, Train Loss: 0.4412, Train AUC: 0.9278  test Loss: 0.4493, test AUC: 0.9149
# Epoch 160/200, Train Loss: 0.4775, Train AUC: 0.9205  test Loss: 0.4626, test AUC: 0.9044
# Epoch 161/200, Train Loss: 0.4460, Train AUC: 0.9279  test Loss: 0.4535, test AUC: 0.9102
# Epoch 162/200, Train Loss: 0.4383, Train AUC: 0.9301  test Loss: 0.4532, test AUC: 0.9133
# Epoch 163/200, Train Loss: 0.4403, Train AUC: 0.9294  test Loss: 0.4505, test AUC: 0.9139
# Epoch 164/200, Train Loss: 0.4434, Train AUC: 0.9276  test Loss: 0.4527, test AUC: 0.9115
# Epoch 165/200, Train Loss: 0.4524, Train AUC: 0.9244  test Loss: 0.4472, test AUC: 0.9130
# Epoch 166/200, Train Loss: 0.4368, Train AUC: 0.9281  test Loss: 0.4551, test AUC: 0.9055
# Epoch 167/200, Train Loss: 0.4344, Train AUC: 0.9288  test Loss: 0.4505, test AUC: 0.9109
# Epoch 168/200, Train Loss: 0.4352, Train AUC: 0.9333  test Loss: 0.4529, test AUC: 0.9072
# Epoch 169/200, Train Loss: 0.4302, Train AUC: 0.9298  test Loss: 0.4483, test AUC: 0.9098
# Epoch 170/200, Train Loss: 0.4609, Train AUC: 0.9261  test Loss: 0.4601, test AUC: 0.9044
# Epoch 171/200, Train Loss: 0.4330, Train AUC: 0.9321  test Loss: 0.4503, test AUC: 0.9114
# Epoch 172/200, Train Loss: 0.4274, Train AUC: 0.9316  test Loss: 0.4488, test AUC: 0.9132
# Epoch 173/200, Train Loss: 0.4342, Train AUC: 0.9301  test Loss: 0.4514, test AUC: 0.9121
# Epoch 174/200, Train Loss: 0.4172, Train AUC: 0.9340  test Loss: 0.4512, test AUC: 0.9088
# Epoch 175/200, Train Loss: 0.4556, Train AUC: 0.9291  test Loss: 0.4619, test AUC: 0.9053
# Epoch 176/200, Train Loss: 0.4179, Train AUC: 0.9363  test Loss: 0.4519, test AUC: 0.9149
# Epoch 177/200, Train Loss: 0.4358, Train AUC: 0.9298  test Loss: 0.4585, test AUC: 0.9048
# Epoch 178/200, Train Loss: 0.4372, Train AUC: 0.9309  test Loss: 0.4496, test AUC: 0.9103
# Epoch 179/200, Train Loss: 0.4366, Train AUC: 0.9302  test Loss: 0.4597, test AUC: 0.9034
# Epoch 180/200, Train Loss: 0.4336, Train AUC: 0.9287  test Loss: 0.4516, test AUC: 0.9118
# Epoch 181/200, Train Loss: 0.4433, Train AUC: 0.9299  test Loss: 0.4578, test AUC: 0.9091
# Epoch 182/200, Train Loss: 0.4427, Train AUC: 0.9274  test Loss: 0.4503, test AUC: 0.9114
# Epoch 183/200, Train Loss: 0.4298, Train AUC: 0.9315  test Loss: 0.4527, test AUC: 0.9087
# Epoch 184/200, Train Loss: 0.4443, Train AUC: 0.9312  test Loss: 0.4746, test AUC: 0.8993
# Epoch 185/200, Train Loss: 0.4331, Train AUC: 0.9318  test Loss: 0.4473, test AUC: 0.9143
# Epoch 186/200, Train Loss: 0.4215, Train AUC: 0.9310  test Loss: 0.4527, test AUC: 0.9084
# Epoch 187/200, Train Loss: 0.4348, Train AUC: 0.9356  test Loss: 0.4595, test AUC: 0.9043
# Epoch 188/200, Train Loss: 0.4281, Train AUC: 0.9332  test Loss: 0.4523, test AUC: 0.9090
# Epoch 189/200, Train Loss: 0.4124, Train AUC: 0.9364  test Loss: 0.4576, test AUC: 0.9107
# Epoch 190/200, Train Loss: 0.4346, Train AUC: 0.9289  test Loss: 0.4512, test AUC: 0.9112
# Epoch 191/200, Train Loss: 0.4182, Train AUC: 0.9342  test Loss: 0.4495, test AUC: 0.9098
# Epoch 192/200, Train Loss: 0.4208, Train AUC: 0.9331  test Loss: 0.4542, test AUC: 0.9098
# Epoch 193/200, Train Loss: 0.4287, Train AUC: 0.9315  test Loss: 0.4679, test AUC: 0.9031
# Epoch 194/200, Train Loss: 0.4196, Train AUC: 0.9356  test Loss: 0.4549, test AUC: 0.9086
# Epoch 195/200, Train Loss: 0.4223, Train AUC: 0.9326  test Loss: 0.4547, test AUC: 0.9080
# Epoch 196/200, Train Loss: 0.4103, Train AUC: 0.9371  test Loss: 0.4549, test AUC: 0.9072
# Epoch 197/200, Train Loss: 0.4284, Train AUC: 0.9357  test Loss: 0.4526, test AUC: 0.9087
# Epoch 198/200, Train Loss: 0.4014, Train AUC: 0.9400  test Loss: 0.4524, test AUC: 0.9077
# Epoch 199/200, Train Loss: 0.4316, Train AUC: 0.9286  test Loss: 0.4530, test AUC: 0.9128
# Epoch 200/200, Train Loss: 0.4269, Train AUC: 0.9304  test Loss: 0.4543, test AUC: 0.9078

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    # 接收新增的 mask 张量
    for inputs, transe_embed, mask, labels in val_loader:
        inputs = inputs.to(device)
        transe_embed = transe_embed.to(device)
        mask = mask.to(device)
        labels = labels.to(device)
        
        # 将 mask 传入模型
        outputs = model(inputs, transe_embed, mask)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.7946
# Recall:    0.7224
# F1 Score:  0.7373
# Precision: 0.7606
# AUC-ROC:   0.9223

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("NACC AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.savefig('NACC_DementiaHKG_plot.png', dpi=300)
plt.close()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("NACC Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.savefig('NACC_DementiaHKG_plot.png', dpi=300)
plt.close()

# %%
import torch
from thop import profile

# 实例化影像提取模型
model_cnn = CNN_3D(num_class=64)

# 构建符合 NiiDataset 输出维度的虚拟输入
dummy_input_img = torch.randn(1, 1, 64, 64, 64)

# 使用 thop 计算指标
flops_cnn, params_cnn = profile(model_cnn, inputs=(dummy_input_img, ))

print("3D-CNN 参数量: %.2f M" % (params_cnn / 1e6))
print("3D-CNN 算力损耗 (FLOPs): %.2f G" % (flops_cnn / 1e9))
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv3d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool3d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# 3D-CNN 参数量: 8.41 M
# 3D-CNN 算力损耗 (FLOPs): 0.57 G

# %%
import torch
from thop import profile

# 1. 影像提取模块 (3D-CNN) 测算
model_cnn = CNN_3D(num_class=64).to(device)
dummy_input_img = torch.randn(1, 1, 64, 64, 64).to(device)
# verbose=False 用于关闭 thop 默认的逐层打印输出
flops_cnn, params_cnn = profile(model_cnn, inputs=(dummy_input_img, ), verbose=False)

# 2. 下游多模态分类模块 (Transformer) 测算
# 根据真实数据维度进行实例化
model_transformer = KGMultiModalTransformer(
    ehr_dim=53, 
    img_dim=64, 
    bio_dim=43, 
    embed_dim=128, 
    num_heads=4, 
    transe_embed_dim=128
).to(device)

# 构建符合数据特征的虚拟输入
dummy_x = torch.randn(1, 160).to(device)
dummy_kg_seq = torch.randn(1, 45, 128).to(device)
dummy_kg_mask = torch.zeros(1, 45, dtype=torch.bool).to(device)

flops_trans, params_trans = profile(model_transformer, inputs=(dummy_x, dummy_kg_seq, dummy_kg_mask), verbose=False)

# 3. 打印统计结果
print("=" * 40)
print("【影像特征提取模块 (3D-CNN)】")
print(f"参数量: {params_cnn / 1e6:.4f} M")
print(f"算力损耗 (FLOPs): {flops_cnn / 1e9:.4f} G")
print("-" * 40)

print("【下游多模态分类模块 (KGMultiModalTransformer)】")
print(f"参数量: {params_trans / 1e6:.4f} M")
print(f"算力损耗 (FLOPs): {flops_trans / 1e9:.4f} G")
print("-" * 40)

print("【总计】")
print(f"总参数量: {(params_cnn + params_trans) / 1e6:.4f} M")
print(f"总算力损耗: {(flops_cnn + flops_trans) / 1e9:.4f} G")
print("=" * 40)
# Out:
# ========================================
# 【影像特征提取模块 (3D-CNN)】
# 参数量: 8.4071 M
# 算力损耗 (FLOPs): 0.5746 G
# ----------------------------------------
# 【下游多模态分类模块 (KGMultiModalTransformer)】
# 参数量: 0.3317 M
# 算力损耗 (FLOPs): 0.0047 G
# ----------------------------------------
# 【总计】
# 总参数量: 8.7388 M
# 总算力损耗: 0.5793 G
# ========================================
