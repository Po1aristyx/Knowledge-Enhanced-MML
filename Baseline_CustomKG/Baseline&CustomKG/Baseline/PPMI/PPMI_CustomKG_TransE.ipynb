# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer_old
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_prodromal=[]
data_swedd=[]
data_control=[]
data_PD = []
count_control = 0
count_PD = 0
count_swedd = 0
count_prodromal = 0
with open('PD1.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'E:/code/PPMI/PD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_PD=count_PD+1
            data_PD.append(row)
            
with open('control.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/PPMI/Control/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_control=count_control+1
            data_control.append(row)
            
with open('swedd.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/PPMI/SWEDD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_swedd=count_swedd+1
            data_swedd.append(row)

with open('prodromal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'E:/code/PPMI/Prodromal/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_prodromal=count_prodromal+1
            data_prodromal.append(row)
print(count_PD) #44
print(count_control) #247
print(count_swedd) #106
print(count_prodromal)
# Out:
# 125
# 132
# 72
# 80

# %%
import numpy as np
import math
import torch
import torch.nn as nn

replace_dict = {
    'F': '0', 'M':'1', 'Normal':'0', 'Slight':'1', 'Mild':'2', 'Moderate':'3', 'Severe':'4',
    'T1-anatomical':'1', 'Processed':'1', 'BL':'0', 'V04':'1', 'V06':'2', 'V08':'4', 'V10':'5',
    'NiFTI':'1', '': '0', 'No':'0', 'Yes':'1', 'Stage 1':'1', 'Stage 2':'2', 'Stage 3':'3', 'Stage 4':'4',
    'On':'1', 'Off':'0', 'Stage 0':'0'
}

ehr_cols = [4, 5]
bio_cols = list(range(12, 45)) + [78, 79]

def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        extracted_row = [row[idx] for idx in target_cols]
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                if math.isnan(val):
                    val = 0.0
            except ValueError:
                val = 0.0 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# %%
pd_ehr_data = preprocess_data(data_PD, replace_dict, ehr_cols)
control_ehr_data = preprocess_data(data_control, replace_dict, ehr_cols)
swedd_ehr_data = preprocess_data(data_swedd, replace_dict, ehr_cols)
prodromal_ehr_data = preprocess_data(data_prodromal, replace_dict, ehr_cols)

pd_EHR = torch.from_numpy(pd_ehr_data).float()
control_EHR = torch.from_numpy(control_ehr_data).float()
swedd_EHR = torch.from_numpy(swedd_ehr_data).float()
prodromal_EHR = torch.from_numpy(prodromal_ehr_data).float()

linear_layer = nn.Linear(2, 1)
pd_EHR = linear_layer(pd_EHR)
control_EHR = linear_layer(control_EHR)
swedd_EHR = linear_layer(swedd_EHR)
prodromal_EHR = linear_layer(prodromal_EHR)

print('pd.EHR--->', pd_EHR.shape)
print('control.EHR--->', control_EHR.shape)
print('swedd.EHR--->', swedd_EHR.shape)
print('prodromal.EHR--->', prodromal_EHR.shape)
# Out:
# pd.EHR---> torch.Size([125, 1])
# control.EHR---> torch.Size([132, 1])
# swedd.EHR---> torch.Size([72, 1])
# prodromal.EHR---> torch.Size([80, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
pd_bio_data = preprocess_data(data_PD, replace_dict, bio_cols)
control_bio_data = preprocess_data(data_control, replace_dict, bio_cols)
swedd_bio_data = preprocess_data(data_swedd, replace_dict, bio_cols)
prodromal_bio_data = preprocess_data(data_prodromal, replace_dict, bio_cols)

pd_tensor = torch.from_numpy(pd_bio_data).float()
control_tensor = torch.from_numpy(control_bio_data).float()
swedd_tensor = torch.from_numpy(swedd_bio_data).float()
prodromal_tensor = torch.from_numpy(prodromal_bio_data).float()

bio_linear = nn.Linear(35, 1)
pd_tensor = bio_linear(pd_tensor)
control_tensor = bio_linear(control_tensor)
swedd_tensor = bio_linear(swedd_tensor)
prodromal_tensor = bio_linear(prodromal_tensor)

print('pd.tensor--->', pd_tensor.shape)
print('control.tensor--->', control_tensor.shape)
print('swedd.tensor--->', swedd_tensor.shape)
print('prodromal.tensor--->', prodromal_tensor.shape)
# Out:
# pd.tensor---> torch.Size([125, 1])
# control.tensor---> torch.Size([132, 1])
# swedd.tensor---> torch.Size([72, 1])
# prodromal.tensor---> torch.Size([80, 1])

# %% [markdown]
# pd_bio_data = preprocess_data(data_PD, replace_dict, bio_cols)
# control_bio_data = preprocess_data(data_control, replace_dict, bio_cols)
# swedd_bio_data = preprocess_data(data_swedd, replace_dict, bio_cols)
# prodromal_bio_data = preprocess_data(data_prodromal, replace_dict, bio_cols)
#
# pd_tensor = torch.from_numpy(pd_bio_data).float()
# control_tensor = torch.from_numpy(control_bio_data).float()
# swedd_tensor = torch.from_numpy(swedd_bio_data).float()
# prodromal_tensor = torch.from_numpy(prodromal_bio_data).float()
#
# bio_linear = nn.Linear(35, 1)
# pd_tensor = bio_linear(pd_tensor)
# control_tensor = bio_linear(control_tensor)
# swedd_tensor = bio_linear(swedd_tensor)
# prodromal_tensor = bio_linear(prodromal_tensor)
#
# print('pd.tensor--->', pd_tensor.shape)
# print('control.tensor--->', control_tensor.shape)
# print('swedd.tensor--->', swedd_tensor.shape)
# print('prodromal.tensor--->', prodromal_tensor.shape)

# %%
def center_crop_3d(tensor, size):
    depth, height, width = tensor.shape
    target_depth, target_height, target_width = size

    start_depth = (depth - target_depth) // 2
    start_height = (height - target_height) // 2
    start_width = (width - target_width) // 2

    end_depth = start_depth + target_depth
    end_height = start_height + target_height
    end_width = start_width + target_width

    return tensor[start_depth:end_depth, start_height:end_height, start_width:end_width]

# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset
import nibabel as nib

# 你的 NiiDataset，务必用这版
class NiiDataset(Dataset):
    def __init__(self, file_list_or_folder):
        if isinstance(file_list_or_folder, list):
            self.file_list = file_list_or_folder
        elif isinstance(file_list_or_folder, str):
            folder_path = file_list_or_folder
            self.file_list = [os.path.join(folder_path, filename)
                              for filename in os.listdir(folder_path)
                              if filename.endswith('.nii') or filename.endswith('.nii.gz')]
        else:
            raise ValueError("参数应为list或str")
    def __len__(self):
        return len(self.file_list)
    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        img = nib.load(file_path)
        img_data = img.get_fdata()
        img_tensor = torch.from_numpy(img_data).float()
        cropped_tensor = center_crop_3d(img_tensor, (64, 64, 64))   # 你的裁剪函数
        input_tensor = cropped_tensor.unsqueeze(0)
        return input_tensor

# 1. 严格用csv顺序生成影像路径
pd_img_paths = [os.path.join('E:/code/PPMI/PD', row[1]) for row in data_PD if os.path.exists(os.path.join('E:/code/PPMI/PD', row[1]))]
control_img_paths = [os.path.join('E:/code/PPMI/Control', row[1]) for row in data_control if os.path.exists(os.path.join('E:/code/PPMI/Control', row[1]))]
swedd_img_paths = [os.path.join('E:/code/PPMI/SWEDD', row[1]) for row in data_swedd if os.path.exists(os.path.join('E:/code/PPMI/SWEDD', row[1]))]
prodromal_img_paths = [os.path.join('E:/code/PPMI/Prodromal', row[1]) for row in data_prodromal if os.path.exists(os.path.join('E:/code/PPMI/Prodromal', row[1]))]

print(f'PD影像数量: {len(pd_img_paths)}')
print(f'Control影像数量: {len(control_img_paths)}')
print(f'SWEDD影像数量: {len(swedd_img_paths)}')
print(f'Prodromal影像数量: {len(prodromal_img_paths)}')

batch_size = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
nii = CNN_3D(num_class=1)
nii = nii.to(device)

# 2. 用于影像特征提取
# PD组
dataset = NiiDataset(pd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
PD_output = torch.cat(all_outputs, dim=0)
print('PD nii shape--->', PD_output.shape)

# Control组
dataset = NiiDataset(control_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
control_output = torch.cat(all_outputs, dim=0)
print('control nii shape--->', control_output.shape)

# Prodromal组
dataset = NiiDataset(prodromal_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
prodromal_output = torch.cat(all_outputs, dim=0)
print('prodromal nii shape--->', prodromal_output.shape)

# SWEDD组
dataset = NiiDataset(swedd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
swedd_output = torch.cat(all_outputs, dim=0)
print('swedd nii shape--->', swedd_output.shape)
# Out:
# PD影像数量: 125
# Control影像数量: 132
# SWEDD影像数量: 72
# Prodromal影像数量: 80
# PD nii shape---> torch.Size([125, 1])
# control nii shape---> torch.Size([132, 1])
# prodromal nii shape---> torch.Size([80, 1])
# swedd nii shape---> torch.Size([72, 1])

# %%
# 定义文件夹路径
nii_folders = {
    'Control': 'Control',
    'PD': 'PD',  
    'Prodromal': 'Prodromal',
    'SWEDD':'SWEDD'
}

# 读取 CSV 文件
pd_df = pd.read_csv('PD1.csv')
control_df = pd.read_csv('control.csv')
prodromal_df = pd.read_csv('prodromal.csv')
swedd_df=pd.read_csv('swedd.csv')


entities = set()
for df in [pd_df, control_df, prodromal_df,swedd_df]:
    for col in df.columns[8:]:
        entities.update(df[col].astype(str).unique())

entities.update(df['Subject'].astype(str).unique())

# 读取 entity2id 映射
entity2id = {}
with open(r'd:/Polaris/Documents/work4/Baseline_CustomKG/Baseline&CustomKG/CustomKG/CustomKG-PPMI.txt', 'r', encoding='utf-8') as f:
    for line in f:
        entity, id = line.strip().split('\t')
        entity2id[entity] = id  

# 初始化实体嵌入
entity_embeddings = torch.from_numpy(np.load(r'd:/Polaris/Documents/work4/Baseline_CustomKG/Baseline&CustomKG/CustomKG/CustomKG-PPMI.npy')).float()

# 定义 TransE 模型类
class TransEextract:
    def __init__(self, entity_embeddings, entity2id):
        self.entity_embeddings = entity_embeddings
        self.entity2id = entity2id
        self.id_to_index = {id: idx for idx, id in enumerate(sorted(entity2id.values()))}

    def get_entity_embedding(self, entity):
        if entity in self.entity2id:
            entity_id = self.entity2id[entity]
            entity_index = self.id_to_index[entity_id]
            return self.entity_embeddings[entity_index]
        else:
            raise ValueError(f"Entity {entity} not found in entity2id mapping")

# 初始化模型
model = TransEextract(entity_embeddings, entity2id)

# 获取嵌入向量
def get_embeddings(df, model, nii_folder):
    embeddings_list = []
    skipped_rows = 0
    for index, row in df.iterrows():
        # 检查 .nii 文件是否存在
        nii_file = row.iloc[1]
        nii_path = os.path.join(nii_folder, nii_file)
        if not os.path.exists(nii_path):
            skipped_rows += 1
            continue
        row_embeddings = []
        for col in df.columns[7:]:
            entity = str(row[col])
            if entity != '0' and entity in model.entity2id:
                row_embeddings.append(model.get_entity_embedding(entity))
        # 将路径和文件名也作为实体
        filename = str(row['Subject'])
        if filename in model.entity2id:
            row_embeddings.append(model.get_entity_embedding(filename))

        
        if row_embeddings:
            mean_embedding = torch.stack(row_embeddings).mean(dim=0)
            embeddings_list.append(mean_embedding)

    
    if not embeddings_list:
        return torch.empty((0, 32))
    return torch.stack(embeddings_list)

# 获取嵌入向量
pd_transe = get_embeddings(pd_df, model, nii_folders['PD'])
control_transe = get_embeddings(control_df, model, nii_folders['Control'])
prodromal_transe = get_embeddings(prodromal_df, model, nii_folders['Prodromal'])
swedd_transe = get_embeddings(swedd_df, model, nii_folders['SWEDD'])

print(pd_transe.shape)
print(control_transe.shape)
print(prodromal_transe.shape)
print(swedd_transe.shape)
# Out:
# torch.Size([125, 32])
# torch.Size([132, 32])
# torch.Size([80, 32])
# torch.Size([72, 32])

# %%
transe_embed_dim = 32

X_pd = torch.cat([pd_EHR, PD_output.cpu(), pd_tensor,pd_transe], dim=1)
X_control = torch.cat([control_EHR, control_output.cpu(), control_tensor,control_transe], dim=1)
X_swedd = torch.cat([swedd_EHR, swedd_output.cpu(), swedd_tensor,swedd_transe], dim=1)
X_prodromal = torch.cat([prodromal_EHR, prodromal_output.cpu(), prodromal_tensor,prodromal_transe], dim=1)

y_pd = torch.ones(len(X_pd)) * 0  # PD 类别标签为 0
y_control = torch.ones(len(X_control)) * 1  # Control 类别标签为 1
y_prodromal = torch.ones(len(X_prodromal)) * 3  # Prodomal 类别标签为 2
y_swedd = torch.ones(len(X_swedd)) * 2  # Swedd 类别标签为 3

# 拼接特征和标签
X = torch.cat([X_pd[:120], X_control, X_prodromal, X_swedd], dim=0).float()
y = torch.cat([y_pd[:120], y_control, y_prodromal, y_swedd], dim=0).float()

features = X[:, :-transe_embed_dim]  
transe_embeddings = X[:, -transe_embed_dim:]  



X_train, X_test, y_train, y_test, transe_train, transe_test = train_test_split(
    features.detach().numpy(), y.numpy(), transe_embeddings.detach().numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)
X_train, X_val, y_train, y_val, transe_train, transe_val = train_test_split(
    X_train, y_train, transe_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)


X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)  # Use LongTensor for classification labels
transe_train_tensor = torch.FloatTensor(transe_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
transe_val_tensor = torch.FloatTensor(transe_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
transe_test_tensor = torch.FloatTensor(transe_test).to(device)


train_dataset = TensorDataset(X_train_tensor, transe_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, transe_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, transe_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
embed_dim = 32
transe_embed_dim = 32
num_epochs = 200
batch_size = 32
learning_rate = 1e-5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
weight_decay = 1e-3

transe_model = TransEModel(num_entities=381, num_relations=2, embed_dim=200)
transe_model.load_state_dict(torch.load('transe.ckpt', map_location=torch.device('cpu')))
transe_model.eval()


model = KGMultiModalTransformer_old(embed_dim=embed_dim, transe_embed_dim=transe_embed_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate,weight_decay=weight_decay)

train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    if epoch % 10 == 0: print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# Epoch 1/200, Train Loss: 1.4468, Train AUC: 0.5093  test Loss: 1.3904, test AUC: 0.5152
# Epoch 2/200, Train Loss: 1.4648, Train AUC: 0.5079  test Loss: 1.3934, test AUC: 0.5261
# Epoch 3/200, Train Loss: 1.4576, Train AUC: 0.5174  test Loss: 1.3979, test AUC: 0.5277
# Epoch 4/200, Train Loss: 1.4446, Train AUC: 0.5249  test Loss: 1.4088, test AUC: 0.5286
# Epoch 5/200, Train Loss: 1.4334, Train AUC: 0.5563  test Loss: 1.4078, test AUC: 0.5351
# Epoch 6/200, Train Loss: 1.4000, Train AUC: 0.5310  test Loss: 1.4203, test AUC: 0.5393
# Epoch 7/200, Train Loss: 1.3899, Train AUC: 0.5577  test Loss: 1.4235, test AUC: 0.5401
# Epoch 8/200, Train Loss: 1.3909, Train AUC: 0.5303  test Loss: 1.4212, test AUC: 0.5399
# Epoch 9/200, Train Loss: 1.3957, Train AUC: 0.5424  test Loss: 1.4188, test AUC: 0.5392
# Epoch 10/200, Train Loss: 1.4033, Train AUC: 0.5306  test Loss: 1.4235, test AUC: 0.5399
# Epoch 11/200, Train Loss: 1.4321, Train AUC: 0.5330  test Loss: 1.4135, test AUC: 0.5472
# Epoch 12/200, Train Loss: 1.4432, Train AUC: 0.5353  test Loss: 1.4157, test AUC: 0.5413
# Epoch 13/200, Train Loss: 1.4014, Train AUC: 0.5362  test Loss: 1.4159, test AUC: 0.5389
# Epoch 14/200, Train Loss: 1.4572, Train AUC: 0.5286  test Loss: 1.4116, test AUC: 0.5474
# Epoch 15/200, Train Loss: 1.3976, Train AUC: 0.5423  test Loss: 1.4106, test AUC: 0.5457
# Epoch 16/200, Train Loss: 1.4007, Train AUC: 0.5455  test Loss: 1.4178, test AUC: 0.5408
# Epoch 17/200, Train Loss: 1.3648, Train AUC: 0.5600  test Loss: 1.4134, test AUC: 0.5445
# Epoch 18/200, Train Loss: 1.3712, Train AUC: 0.5599  test Loss: 1.4133, test AUC: 0.5450
# Epoch 19/200, Train Loss: 1.3909, Train AUC: 0.5650  test Loss: 1.4085, test AUC: 0.5489
# Epoch 20/200, Train Loss: 1.3841, Train AUC: 0.5578  test Loss: 1.4134, test AUC: 0.5487
# Epoch 21/200, Train Loss: 1.4387, Train AUC: 0.5449  test Loss: 1.4035, test AUC: 0.5579
# Epoch 22/200, Train Loss: 1.4031, Train AUC: 0.5418  test Loss: 1.4023, test AUC: 0.5543
# Epoch 23/200, Train Loss: 1.3752, Train AUC: 0.5592  test Loss: 1.4054, test AUC: 0.5522
# Epoch 24/200, Train Loss: 1.4125, Train AUC: 0.5621  test Loss: 1.4038, test AUC: 0.5515
# Epoch 25/200, Train Loss: 1.4219, Train AUC: 0.5380  test Loss: 1.4041, test AUC: 0.5526
# Epoch 26/200, Train Loss: 1.3887, Train AUC: 0.5617  test Loss: 1.4088, test AUC: 0.5527
# Epoch 27/200, Train Loss: 1.3976, Train AUC: 0.5533  test Loss: 1.4039, test AUC: 0.5623
# Epoch 28/200, Train Loss: 1.4046, Train AUC: 0.5505  test Loss: 1.4061, test AUC: 0.5540
# Epoch 29/200, Train Loss: 1.3609, Train AUC: 0.5756  test Loss: 1.4083, test AUC: 0.5570
# Epoch 30/200, Train Loss: 1.3937, Train AUC: 0.5445  test Loss: 1.4100, test AUC: 0.5596
# Epoch 31/200, Train Loss: 1.3267, Train AUC: 0.6034  test Loss: 1.4036, test AUC: 0.5685
# Epoch 32/200, Train Loss: 1.3677, Train AUC: 0.5916  test Loss: 1.3974, test AUC: 0.5655
# Epoch 33/200, Train Loss: 1.3706, Train AUC: 0.6098  test Loss: 1.3934, test AUC: 0.5693
# Epoch 34/200, Train Loss: 1.3715, Train AUC: 0.5702  test Loss: 1.3877, test AUC: 0.5711
# Epoch 35/200, Train Loss: 1.3866, Train AUC: 0.5917  test Loss: 1.3843, test AUC: 0.5815
# Epoch 36/200, Train Loss: 1.4036, Train AUC: 0.5572  test Loss: 1.3826, test AUC: 0.5778
# Epoch 37/200, Train Loss: 1.3880, Train AUC: 0.5923  test Loss: 1.3896, test AUC: 0.5678
# Epoch 38/200, Train Loss: 1.3701, Train AUC: 0.5722  test Loss: 1.3854, test AUC: 0.5720
# Epoch 39/200, Train Loss: 1.3371, Train AUC: 0.5844  test Loss: 1.3891, test AUC: 0.5702
# Epoch 40/200, Train Loss: 1.3589, Train AUC: 0.5700  test Loss: 1.3892, test AUC: 0.5664
# Epoch 41/200, Train Loss: 1.3388, Train AUC: 0.5863  test Loss: 1.3813, test AUC: 0.5850
# Epoch 42/200, Train Loss: 1.4057, Train AUC: 0.5887  test Loss: 1.3897, test AUC: 0.5753
# Epoch 43/200, Train Loss: 1.3754, Train AUC: 0.5930  test Loss: 1.3904, test AUC: 0.5736
# Epoch 44/200, Train Loss: 1.3410, Train AUC: 0.5940  test Loss: 1.3924, test AUC: 0.5665
# Epoch 45/200, Train Loss: 1.3679, Train AUC: 0.5722  test Loss: 1.3867, test AUC: 0.5787
# Epoch 46/200, Train Loss: 1.3333, Train AUC: 0.6102  test Loss: 1.3793, test AUC: 0.5776
# Epoch 47/200, Train Loss: 1.3371, Train AUC: 0.6259  test Loss: 1.3839, test AUC: 0.5785
# Epoch 48/200, Train Loss: 1.4017, Train AUC: 0.5655  test Loss: 1.3873, test AUC: 0.5729
# Epoch 49/200, Train Loss: 1.3817, Train AUC: 0.6011  test Loss: 1.3851, test AUC: 0.5790
# Epoch 50/200, Train Loss: 1.3730, Train AUC: 0.5826  test Loss: 1.3831, test AUC: 0.5771
# Epoch 51/200, Train Loss: 1.3511, Train AUC: 0.5850  test Loss: 1.3757, test AUC: 0.5873
# Epoch 52/200, Train Loss: 1.3850, Train AUC: 0.5668  test Loss: 1.3791, test AUC: 0.5829
# Epoch 53/200, Train Loss: 1.3668, Train AUC: 0.5796  test Loss: 1.3825, test AUC: 0.5900
# Epoch 54/200, Train Loss: 1.3738, Train AUC: 0.6121  test Loss: 1.3800, test AUC: 0.5827
# Epoch 55/200, Train Loss: 1.3029, Train AUC: 0.6231  test Loss: 1.3780, test AUC: 0.5839
# Epoch 56/200, Train Loss: 1.3590, Train AUC: 0.6190  test Loss: 1.3757, test AUC: 0.5875
# Epoch 57/200, Train Loss: 1.4049, Train AUC: 0.5887  test Loss: 1.3715, test AUC: 0.5934
# Epoch 58/200, Train Loss: 1.4134, Train AUC: 0.5720  test Loss: 1.3696, test AUC: 0.5886
# Epoch 59/200, Train Loss: 1.3908, Train AUC: 0.5923  test Loss: 1.3752, test AUC: 0.5719
# Epoch 60/200, Train Loss: 1.3570, Train AUC: 0.6231  test Loss: 1.3722, test AUC: 0.5843
# Epoch 61/200, Train Loss: 1.3902, Train AUC: 0.5736  test Loss: 1.3669, test AUC: 0.5849
# Epoch 62/200, Train Loss: 1.3318, Train AUC: 0.6007  test Loss: 1.3826, test AUC: 0.5759
# Epoch 63/200, Train Loss: 1.4207, Train AUC: 0.5876  test Loss: 1.3797, test AUC: 0.5775
# Epoch 64/200, Train Loss: 1.3506, Train AUC: 0.6199  test Loss: 1.3805, test AUC: 0.5758
# Epoch 65/200, Train Loss: 1.4171, Train AUC: 0.6228  test Loss: 1.3807, test AUC: 0.5707
# Epoch 66/200, Train Loss: 1.3670, Train AUC: 0.5924  test Loss: 1.3643, test AUC: 0.5893
# Epoch 67/200, Train Loss: 1.3346, Train AUC: 0.5982  test Loss: 1.3678, test AUC: 0.5870
# Epoch 68/200, Train Loss: 1.3698, Train AUC: 0.6267  test Loss: 1.3729, test AUC: 0.5870
# Epoch 69/200, Train Loss: 1.3631, Train AUC: 0.6283  test Loss: 1.3710, test AUC: 0.5932
# Epoch 70/200, Train Loss: 1.3304, Train AUC: 0.6321  test Loss: 1.3778, test AUC: 0.5847
# Epoch 71/200, Train Loss: 1.2893, Train AUC: 0.6304  test Loss: 1.3756, test AUC: 0.5926
# Epoch 72/200, Train Loss: 1.3187, Train AUC: 0.6119  test Loss: 1.3640, test AUC: 0.5976
# Epoch 73/200, Train Loss: 1.3847, Train AUC: 0.5871  test Loss: 1.3715, test AUC: 0.5932
# Epoch 74/200, Train Loss: 1.4232, Train AUC: 0.6055  test Loss: 1.3641, test AUC: 0.5940
# Epoch 75/200, Train Loss: 1.3089, Train AUC: 0.6369  test Loss: 1.3682, test AUC: 0.5942
# Epoch 76/200, Train Loss: 1.3216, Train AUC: 0.5989  test Loss: 1.3652, test AUC: 0.5901
# Epoch 77/200, Train Loss: 1.3608, Train AUC: 0.5911  test Loss: 1.3736, test AUC: 0.5907
# Epoch 78/200, Train Loss: 1.3376, Train AUC: 0.6108  test Loss: 1.3684, test AUC: 0.5872
# Epoch 79/200, Train Loss: 1.2868, Train AUC: 0.6569  test Loss: 1.3671, test AUC: 0.5897
# Epoch 80/200, Train Loss: 1.3784, Train AUC: 0.6173  test Loss: 1.3611, test AUC: 0.5935
# Epoch 81/200, Train Loss: 1.3442, Train AUC: 0.6209  test Loss: 1.3583, test AUC: 0.5942
# Epoch 82/200, Train Loss: 1.3417, Train AUC: 0.6075  test Loss: 1.3602, test AUC: 0.5960
# Epoch 83/200, Train Loss: 1.3680, Train AUC: 0.6372  test Loss: 1.3631, test AUC: 0.5960
# Epoch 84/200, Train Loss: 1.3646, Train AUC: 0.6307  test Loss: 1.3667, test AUC: 0.5943
# Epoch 85/200, Train Loss: 1.3397, Train AUC: 0.6116  test Loss: 1.3760, test AUC: 0.5879
# Epoch 86/200, Train Loss: 1.3540, Train AUC: 0.6367  test Loss: 1.3624, test AUC: 0.5998
# Epoch 87/200, Train Loss: 1.3121, Train AUC: 0.6331  test Loss: 1.3572, test AUC: 0.6024
# Epoch 88/200, Train Loss: 1.3366, Train AUC: 0.6176  test Loss: 1.3505, test AUC: 0.6065
# Epoch 89/200, Train Loss: 1.3045, Train AUC: 0.6417  test Loss: 1.3524, test AUC: 0.6124
# Epoch 90/200, Train Loss: 1.3670, Train AUC: 0.6244  test Loss: 1.3590, test AUC: 0.5991
# Epoch 91/200, Train Loss: 1.3297, Train AUC: 0.6221  test Loss: 1.3546, test AUC: 0.6033
# Epoch 92/200, Train Loss: 1.3385, Train AUC: 0.6364  test Loss: 1.3551, test AUC: 0.6009
# Epoch 93/200, Train Loss: 1.2933, Train AUC: 0.6534  test Loss: 1.3531, test AUC: 0.6013
# Epoch 94/200, Train Loss: 1.3241, Train AUC: 0.6231  test Loss: 1.3474, test AUC: 0.6068
# Epoch 95/200, Train Loss: 1.3150, Train AUC: 0.6256  test Loss: 1.3510, test AUC: 0.6037
# Epoch 96/200, Train Loss: 1.2932, Train AUC: 0.6404  test Loss: 1.3570, test AUC: 0.5936
# Epoch 97/200, Train Loss: 1.2742, Train AUC: 0.6564  test Loss: 1.3614, test AUC: 0.5938
# Epoch 98/200, Train Loss: 1.2900, Train AUC: 0.6616  test Loss: 1.3570, test AUC: 0.5970
# Epoch 99/200, Train Loss: 1.3105, Train AUC: 0.6382  test Loss: 1.3568, test AUC: 0.6045
# Epoch 100/200, Train Loss: 1.3185, Train AUC: 0.6534  test Loss: 1.3506, test AUC: 0.6122
# Epoch 101/200, Train Loss: 1.3502, Train AUC: 0.6392  test Loss: 1.3523, test AUC: 0.6056
# Epoch 102/200, Train Loss: 1.3005, Train AUC: 0.6522  test Loss: 1.3488, test AUC: 0.6087
# Epoch 103/200, Train Loss: 1.2597, Train AUC: 0.6509  test Loss: 1.3522, test AUC: 0.6096
# Epoch 104/200, Train Loss: 1.3018, Train AUC: 0.6723  test Loss: 1.3423, test AUC: 0.6082
# Epoch 105/200, Train Loss: 1.3525, Train AUC: 0.6225  test Loss: 1.3480, test AUC: 0.6038
# Epoch 106/200, Train Loss: 1.3606, Train AUC: 0.6333  test Loss: 1.3516, test AUC: 0.6056
# Epoch 107/200, Train Loss: 1.3028, Train AUC: 0.6395  test Loss: 1.3494, test AUC: 0.6078
# Epoch 108/200, Train Loss: 1.3456, Train AUC: 0.6373  test Loss: 1.3429, test AUC: 0.6078
# Epoch 109/200, Train Loss: 1.3316, Train AUC: 0.6388  test Loss: 1.3456, test AUC: 0.6108
# Epoch 110/200, Train Loss: 1.2959, Train AUC: 0.6543  test Loss: 1.3479, test AUC: 0.6121
# Epoch 111/200, Train Loss: 1.3507, Train AUC: 0.6473  test Loss: 1.3492, test AUC: 0.6099
# Epoch 112/200, Train Loss: 1.3343, Train AUC: 0.6368  test Loss: 1.3518, test AUC: 0.5968
# Epoch 113/200, Train Loss: 1.3233, Train AUC: 0.6816  test Loss: 1.3433, test AUC: 0.6081
# Epoch 114/200, Train Loss: 1.2871, Train AUC: 0.6534  test Loss: 1.3442, test AUC: 0.6083
# Epoch 115/200, Train Loss: 1.3036, Train AUC: 0.6471  test Loss: 1.3406, test AUC: 0.6092
# Epoch 116/200, Train Loss: 1.3625, Train AUC: 0.6451  test Loss: 1.3383, test AUC: 0.6181
# Epoch 117/200, Train Loss: 1.2920, Train AUC: 0.6588  test Loss: 1.3376, test AUC: 0.6185
# Epoch 118/200, Train Loss: 1.2975, Train AUC: 0.6666  test Loss: 1.3385, test AUC: 0.6201
# Epoch 119/200, Train Loss: 1.2968, Train AUC: 0.6411  test Loss: 1.3376, test AUC: 0.6191
# Epoch 120/200, Train Loss: 1.3173, Train AUC: 0.6462  test Loss: 1.3380, test AUC: 0.6204
# Epoch 121/200, Train Loss: 1.2984, Train AUC: 0.6642  test Loss: 1.3401, test AUC: 0.6162
# Epoch 122/200, Train Loss: 1.3683, Train AUC: 0.6340  test Loss: 1.3320, test AUC: 0.6236
# Epoch 123/200, Train Loss: 1.2964, Train AUC: 0.6342  test Loss: 1.3342, test AUC: 0.6225
# Epoch 124/200, Train Loss: 1.2978, Train AUC: 0.6702  test Loss: 1.3362, test AUC: 0.6167
# Epoch 125/200, Train Loss: 1.2921, Train AUC: 0.6544  test Loss: 1.3407, test AUC: 0.6120
# Epoch 126/200, Train Loss: 1.3079, Train AUC: 0.6551  test Loss: 1.3324, test AUC: 0.6159
# Epoch 127/200, Train Loss: 1.3334, Train AUC: 0.6716  test Loss: 1.3430, test AUC: 0.6121
# Epoch 128/200, Train Loss: 1.3330, Train AUC: 0.6660  test Loss: 1.3383, test AUC: 0.6185
# Epoch 129/200, Train Loss: 1.3137, Train AUC: 0.6450  test Loss: 1.3341, test AUC: 0.6181
# Epoch 130/200, Train Loss: 1.3193, Train AUC: 0.6586  test Loss: 1.3270, test AUC: 0.6249
# Epoch 131/200, Train Loss: 1.3358, Train AUC: 0.6481  test Loss: 1.3361, test AUC: 0.6188
# Epoch 132/200, Train Loss: 1.3245, Train AUC: 0.6431  test Loss: 1.3377, test AUC: 0.6103
# Epoch 133/200, Train Loss: 1.2641, Train AUC: 0.6734  test Loss: 1.3328, test AUC: 0.6215
# Epoch 134/200, Train Loss: 1.3433, Train AUC: 0.6519  test Loss: 1.3292, test AUC: 0.6215
# Epoch 135/200, Train Loss: 1.2847, Train AUC: 0.6625  test Loss: 1.3296, test AUC: 0.6233
# Epoch 136/200, Train Loss: 1.2575, Train AUC: 0.6566  test Loss: 1.3326, test AUC: 0.6212
# Epoch 137/200, Train Loss: 1.2430, Train AUC: 0.6737  test Loss: 1.3394, test AUC: 0.6203
# Epoch 138/200, Train Loss: 1.3054, Train AUC: 0.6511  test Loss: 1.3308, test AUC: 0.6210
# Epoch 139/200, Train Loss: 1.3260, Train AUC: 0.6470  test Loss: 1.3258, test AUC: 0.6322
# Epoch 140/200, Train Loss: 1.2766, Train AUC: 0.6568  test Loss: 1.3343, test AUC: 0.6202
# Epoch 141/200, Train Loss: 1.2788, Train AUC: 0.6846  test Loss: 1.3271, test AUC: 0.6251
# Epoch 142/200, Train Loss: 1.2725, Train AUC: 0.6641  test Loss: 1.3254, test AUC: 0.6272
# Epoch 143/200, Train Loss: 1.2511, Train AUC: 0.6714  test Loss: 1.3282, test AUC: 0.6241
# Epoch 144/200, Train Loss: 1.3130, Train AUC: 0.6712  test Loss: 1.3226, test AUC: 0.6298
# Epoch 145/200, Train Loss: 1.3177, Train AUC: 0.6548  test Loss: 1.3208, test AUC: 0.6260
# Epoch 146/200, Train Loss: 1.3110, Train AUC: 0.6795  test Loss: 1.3206, test AUC: 0.6252
# Epoch 147/200, Train Loss: 1.3235, Train AUC: 0.6604  test Loss: 1.3253, test AUC: 0.6223
# Epoch 148/200, Train Loss: 1.2782, Train AUC: 0.6848  test Loss: 1.3252, test AUC: 0.6217
# Epoch 149/200, Train Loss: 1.2880, Train AUC: 0.6732  test Loss: 1.3262, test AUC: 0.6263
# Epoch 150/200, Train Loss: 1.2784, Train AUC: 0.6986  test Loss: 1.3285, test AUC: 0.6227
# Epoch 151/200, Train Loss: 1.2698, Train AUC: 0.6759  test Loss: 1.3209, test AUC: 0.6249
# Epoch 152/200, Train Loss: 1.3078, Train AUC: 0.6695  test Loss: 1.3303, test AUC: 0.6237
# Epoch 153/200, Train Loss: 1.2607, Train AUC: 0.6797  test Loss: 1.3227, test AUC: 0.6314
# Epoch 154/200, Train Loss: 1.3225, Train AUC: 0.6679  test Loss: 1.3220, test AUC: 0.6338
# Epoch 155/200, Train Loss: 1.2917, Train AUC: 0.6844  test Loss: 1.3168, test AUC: 0.6398
# Epoch 156/200, Train Loss: 1.3269, Train AUC: 0.6769  test Loss: 1.3191, test AUC: 0.6404
# Epoch 157/200, Train Loss: 1.3220, Train AUC: 0.6914  test Loss: 1.3196, test AUC: 0.6357
# Epoch 158/200, Train Loss: 1.2564, Train AUC: 0.6787  test Loss: 1.3217, test AUC: 0.6328
# Epoch 159/200, Train Loss: 1.2877, Train AUC: 0.6764  test Loss: 1.3155, test AUC: 0.6343
# Epoch 160/200, Train Loss: 1.2963, Train AUC: 0.6695  test Loss: 1.3249, test AUC: 0.6220
# Epoch 161/200, Train Loss: 1.2493, Train AUC: 0.6835  test Loss: 1.3212, test AUC: 0.6293
# Epoch 162/200, Train Loss: 1.3073, Train AUC: 0.6647  test Loss: 1.3170, test AUC: 0.6311
# Epoch 163/200, Train Loss: 1.2326, Train AUC: 0.6857  test Loss: 1.3186, test AUC: 0.6247
# Epoch 164/200, Train Loss: 1.2620, Train AUC: 0.6766  test Loss: 1.3194, test AUC: 0.6298
# Epoch 165/200, Train Loss: 1.3062, Train AUC: 0.6918  test Loss: 1.3088, test AUC: 0.6368
# Epoch 166/200, Train Loss: 1.2897, Train AUC: 0.6995  test Loss: 1.3083, test AUC: 0.6368
# Epoch 167/200, Train Loss: 1.2677, Train AUC: 0.7086  test Loss: 1.3109, test AUC: 0.6391
# Epoch 168/200, Train Loss: 1.2725, Train AUC: 0.6789  test Loss: 1.3099, test AUC: 0.6346
# Epoch 169/200, Train Loss: 1.2435, Train AUC: 0.6996  test Loss: 1.3124, test AUC: 0.6336
# Epoch 170/200, Train Loss: 1.2512, Train AUC: 0.7073  test Loss: 1.2968, test AUC: 0.6461
# Epoch 171/200, Train Loss: 1.2451, Train AUC: 0.6910  test Loss: 1.3063, test AUC: 0.6394
# Epoch 172/200, Train Loss: 1.2705, Train AUC: 0.6805  test Loss: 1.3098, test AUC: 0.6389
# Epoch 173/200, Train Loss: 1.2518, Train AUC: 0.6971  test Loss: 1.3067, test AUC: 0.6437
# Epoch 174/200, Train Loss: 1.2393, Train AUC: 0.6932  test Loss: 1.3059, test AUC: 0.6413
# Epoch 175/200, Train Loss: 1.3077, Train AUC: 0.6680  test Loss: 1.3057, test AUC: 0.6396
# Epoch 176/200, Train Loss: 1.2683, Train AUC: 0.6815  test Loss: 1.3146, test AUC: 0.6351
# Epoch 177/200, Train Loss: 1.2297, Train AUC: 0.7285  test Loss: 1.3058, test AUC: 0.6425
# Epoch 178/200, Train Loss: 1.2694, Train AUC: 0.7186  test Loss: 1.3109, test AUC: 0.6392
# Epoch 179/200, Train Loss: 1.3182, Train AUC: 0.7101  test Loss: 1.3051, test AUC: 0.6451
# Epoch 180/200, Train Loss: 1.2389, Train AUC: 0.6926  test Loss: 1.3060, test AUC: 0.6391
# Epoch 181/200, Train Loss: 1.2530, Train AUC: 0.6919  test Loss: 1.3055, test AUC: 0.6423
# Epoch 182/200, Train Loss: 1.2372, Train AUC: 0.6770  test Loss: 1.3052, test AUC: 0.6440
# Epoch 183/200, Train Loss: 1.3121, Train AUC: 0.6951  test Loss: 1.3017, test AUC: 0.6490
# Epoch 184/200, Train Loss: 1.2371, Train AUC: 0.6925  test Loss: 1.2992, test AUC: 0.6474
# Epoch 185/200, Train Loss: 1.2577, Train AUC: 0.6855  test Loss: 1.2971, test AUC: 0.6522
# Epoch 186/200, Train Loss: 1.2837, Train AUC: 0.6941  test Loss: 1.2998, test AUC: 0.6408
# Epoch 187/200, Train Loss: 1.2774, Train AUC: 0.6850  test Loss: 1.3025, test AUC: 0.6420
# Epoch 188/200, Train Loss: 1.2595, Train AUC: 0.7016  test Loss: 1.3011, test AUC: 0.6481
# Epoch 189/200, Train Loss: 1.2521, Train AUC: 0.6919  test Loss: 1.2983, test AUC: 0.6497
# Epoch 190/200, Train Loss: 1.3057, Train AUC: 0.6911  test Loss: 1.2972, test AUC: 0.6472
# Epoch 191/200, Train Loss: 1.2545, Train AUC: 0.6947  test Loss: 1.3030, test AUC: 0.6437
# Epoch 192/200, Train Loss: 1.2489, Train AUC: 0.7027  test Loss: 1.3035, test AUC: 0.6434
# Epoch 193/200, Train Loss: 1.2910, Train AUC: 0.6842  test Loss: 1.3006, test AUC: 0.6487
# Epoch 194/200, Train Loss: 1.2247, Train AUC: 0.7230  test Loss: 1.2936, test AUC: 0.6541
# Epoch 195/200, Train Loss: 1.2748, Train AUC: 0.6831  test Loss: 1.2968, test AUC: 0.6503
# Epoch 196/200, Train Loss: 1.2283, Train AUC: 0.7185  test Loss: 1.2933, test AUC: 0.6552
# Epoch 197/200, Train Loss: 1.2667, Train AUC: 0.6990  test Loss: 1.2983, test AUC: 0.6492
# Epoch 198/200, Train Loss: 1.1844, Train AUC: 0.7108  test Loss: 1.2928, test AUC: 0.6540
# Epoch 199/200, Train Loss: 1.2512, Train AUC: 0.6826  test Loss: 1.2909, test AUC: 0.6507
# Epoch 200/200, Train Loss: 1.2447, Train AUC: 0.7008  test Loss: 1.2844, test AUC: 0.6625

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.3538
# Precision: 0.3147
# Recall:    0.3271
# F1 Score:  0.3130
# AUC-ROC:   0.6160

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("PPMI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.savefig('PPMI_CustomKG_TransE_plot.png', dpi=300)
plt.close()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("PPMI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.savefig('PPMI_CustomKG_TransE_plot.png', dpi=300)
plt.close()
